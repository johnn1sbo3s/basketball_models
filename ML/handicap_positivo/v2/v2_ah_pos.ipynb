# %%
import pandas as pd; pd.set_option('display.max_columns', None)
import numpy as np
import random
import matplotlib.pyplot as plt
from pycaret.classification import *

import sys
sys.path.append('../../../scripts/')
from PreparaDataset import *

# %% [markdown]
# # Parâmetros do método

# %%
TARGET = 'Back_HA_Zebra'
ODDS = 'Odds'

# %% [markdown]
# # Carregando o dataset

# %%
data = pd.read_csv('../../../data/Entire_Season.csv')

# %%
def prepara_dataset(_df):
    # HA
    _df.loc[(_df['Back_HA_H']) == 0, 'Back_HA_A'] = 1
    _df.loc[(_df['Back_HA_H']) == 1, 'Back_HA_A'] = 0
    _df.loc[(_df['Back_HA_H']) == 2, 'Back_HA_A'] = 2

    _df.loc[(_df['HA_Line']) > 0, 'Zebra'] = 'Casa'
    _df.loc[(_df['HA_Line']) < 0, 'Zebra'] = 'Fora'
    _df['Zebra'] = _df['Zebra'].astype('category')

    # Odds
    _df.loc[(_df['Zebra']) == 'Casa', 'Odds'] = _df['HA_Odds_H']
    _df.loc[(_df['Zebra']) == 'Fora', 'Odds'] = _df['HA_Odds_A']

    _df.loc[((_df['Zebra'] == 'Casa') & (_df['Back_HA_H'] == 1)), 'Back_HA_Zebra'] = 1
    _df.loc[((_df['Zebra'] == 'Casa') & (_df['Back_HA_H'] == 0)), 'Back_HA_Zebra'] = 0
    _df.loc[((_df['Zebra'] == 'Fora') & (_df['Back_HA_A'] == 1)), 'Back_HA_Zebra'] = 1
    _df.loc[((_df['Zebra'] == 'Fora') & (_df['Back_HA_A'] == 0)), 'Back_HA_Zebra'] = 0

    _df.reset_index(drop=True, inplace=True)

    # Limpa _df
    _df.replace([np.inf, -np.inf], 0, inplace=True)
    _df.dropna(subset=[TARGET], inplace=True)
    # _df = _df[(_df['Avg_CG_H'] != 0) & (_df['Avg_CG_A'] != 0) & (_df['DP_CG_H'] != 0) & (_df['DP_CG_A'] != 0) & (_df['MediaCustoGolAway'] != 0)]
    
    return _df

# %%
df = prepara_df(data)
df = prepara_dataset(df)

# %%
# TRAIN_SIZE = 0.625
# div = int(TRAIN_SIZE * len(df))

div = 3000
treino = df.iloc[:div, :]
val = df.iloc[div: , :]

print(f'Treino: {treino.shape[0]} | Validação: {val.shape[0]}')
print(f"Odd média: {treino[ODDS].mean():.2f}")
print(f"WR: {treino[TARGET].mean():.2f} (Odd justa: {1 / treino[TARGET].mean():.2f})")
# Out:
# Treino: 3000 | Validação: 2305
# Odd média: 1.90
# WR: 0.51 (Odd justa: 1.96)

# %% [markdown]
# # Validação 2

# %%
val1 = val[val['Date'] < '2023-10-20']
val2 = val[val['Date'] > '2023-10-19']

print(f'Validação 1: {val1.shape[0]} | Validação 2: {val2.shape[0]}')
# Out:
# Validação 1: 2146 | Validação 2: 159

# %% [markdown]
# # Criação do modelo

# %%
features = ['Odds_H', 'Odds_A', 'Over_Line', 'Odds_Over', 'Odds_Under', 'HA_Line',
       'HA_Odds_H', 'HA_Odds_A', 'P(H)', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'Porc_Over_Home',
       'Porc_Over_Away', 'Avg_CG_H', 'DP_CG_H',
       'CV_CG_H', 'Avg_CG_A', 'DP_CG_A', 'CV_CG_A', 'MediaCustoGolHome',
       'MediaCustoGolAway', 'Last_CG_H', 'Last_CG_A', 'Acima_Last_CG_H',
       'Acima_Last_CG_A', 'Abaixo_Last_CG_H', 'Abaixo_Last_CG_A', 'CV_ML',
       'CV_Over', 'CV_HA', 'Retornos_BH_Acu', 'Avg_Retornos_BH', 'Custo_Retorno_BH',
       'Avg_Porc_BH_Bookie', 'Avg_Porc_BH_Real', 'Dist_Porc_BH',
       'Retornos_BA_Acu', 'Avg_Retornos_BA', 'Custo_Retorno_BA',
       'Avg_Porc_BA_Bookie', 'Avg_Porc_BA_Real', 'Dist_Porc_BA', ODDS]

features = ['Odds_H', 'Odds_A', 'Odds_Over', 'Odds_Under', 'Over_Line',  'HA_Line', 'HA_Odds_H', 'HA_Odds_A', 'P(H)', 'P(A)', 
       'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'CV_HA', ODDS]

features = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']

# %%
def cria_setup(seed = 2023, features = features):
    cls = setup(data = treino,
            ignore_features = [x for x in treino.columns.to_list() if x not in features and x != TARGET],
            target = TARGET,
            train_size = 0.5,
            normalize = True,
            normalize_method = 'minmax',
            session_id = seed,
            remove_outliers = True,
            fix_imbalance = True,
            verbose = False
            )

# %%
cria_setup(seed = 2023, features = features)

xtrain_treino = get_config('X_train')
ytrain_treino = get_config('y_train')
xtrain_teste = get_config('X_test')
ytrain_teste = get_config('y_test')

real_treino = pd.concat([xtrain_treino, ytrain_treino], axis=1)
real_teste = pd.concat([xtrain_teste, ytrain_teste],  axis=1)

# %%
top = compare_models(exclude=['catboost', 'dummy'], fold = 5, sort='precision', n_select=14)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:29:29
# Status     . . . . . . . . . . . . . . . . . .      Fitting 5 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <style type="text/css">
# #T_92e45 th {
#   text-align: left;
# }
# #T_92e45_row0_col0, #T_92e45_row1_col0, #T_92e45_row1_col1, #T_92e45_row1_col2, #T_92e45_row1_col3, #T_92e45_row1_col4, #T_92e45_row1_col5, #T_92e45_row1_col6, #T_92e45_row1_col7, #T_92e45_row2_col0, #T_92e45_row2_col1, #T_92e45_row2_col2, #T_92e45_row2_col3, #T_92e45_row2_col4, #T_92e45_row2_col5, #T_92e45_row2_col6, #T_92e45_row2_col7, #T_92e45_row3_col0, #T_92e45_row3_col1, #T_92e45_row3_col2, #T_92e45_row3_col3, #T_92e45_row3_col4, #T_92e45_row3_col5, #T_92e45_row3_col6, #T_92e45_row3_col7, #T_92e45_row4_col0, #T_92e45_row4_col1, #T_92e45_row4_col2, #T_92e45_row4_col3, #T_92e45_row4_col4, #T_92e45_row4_col5, #T_92e45_row4_col6, #T_92e45_row4_col7, #T_92e45_row5_col0, #T_92e45_row5_col1, #T_92e45_row5_col2, #T_92e45_row5_col3, #T_92e45_row5_col4, #T_92e45_row5_col5, #T_92e45_row5_col6, #T_92e45_row5_col7, #T_92e45_row6_col0, #T_92e45_row6_col1, #T_92e45_row6_col2, #T_92e45_row6_col3, #T_92e45_row6_col4, #T_92e45_row6_col5, #T_92e45_row6_col6, #T_92e45_row6_col7, #T_92e45_row7_col0, #T_92e45_row7_col1, #T_92e45_row7_col2, #T_92e45_row7_col3, #T_92e45_row7_col4, #T_92e45_row7_col5, #T_92e45_row7_col6, #T_92e45_row7_col7, #T_92e45_row8_col0, #T_92e45_row8_col1, #T_92e45_row8_col2, #T_92e45_row8_col3, #T_92e45_row8_col4, #T_92e45_row8_col5, #T_92e45_row8_col6, #T_92e45_row8_col7, #T_92e45_row9_col0, #T_92e45_row9_col1, #T_92e45_row9_col2, #T_92e45_row9_col3, #T_92e45_row9_col4, #T_92e45_row9_col5, #T_92e45_row9_col6, #T_92e45_row9_col7, #T_92e45_row10_col0, #T_92e45_row10_col1, #T_92e45_row10_col2, #T_92e45_row10_col3, #T_92e45_row10_col4, #T_92e45_row10_col5, #T_92e45_row10_col6, #T_92e45_row10_col7, #T_92e45_row11_col0, #T_92e45_row11_col1, #T_92e45_row11_col2, #T_92e45_row11_col3, #T_92e45_row11_col4, #T_92e45_row11_col5, #T_92e45_row11_col6, #T_92e45_row11_col7, #T_92e45_row12_col0, #T_92e45_row12_col1, #T_92e45_row12_col2, #T_92e45_row12_col3, #T_92e45_row12_col4, #T_92e45_row12_col5, #T_92e45_row12_col6, #T_92e45_row12_col7, #T_92e45_row13_col0, #T_92e45_row13_col1, #T_92e45_row13_col2, #T_92e45_row13_col3, #T_92e45_row13_col4, #T_92e45_row13_col5, #T_92e45_row13_col6, #T_92e45_row13_col7 {
#   text-align: left;
# }
# #T_92e45_row0_col1, #T_92e45_row0_col2, #T_92e45_row0_col3, #T_92e45_row0_col4, #T_92e45_row0_col5, #T_92e45_row0_col6, #T_92e45_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_92e45_row0_col8, #T_92e45_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_92e45_row1_col8, #T_92e45_row2_col8, #T_92e45_row3_col8, #T_92e45_row4_col8, #T_92e45_row5_col8, #T_92e45_row6_col8, #T_92e45_row7_col8, #T_92e45_row8_col8, #T_92e45_row9_col8, #T_92e45_row10_col8, #T_92e45_row11_col8, #T_92e45_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_92e45">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92e45_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_92e45_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_92e45_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_92e45_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_92e45_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_92e45_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_92e45_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_92e45_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_92e45_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92e45_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_92e45_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_92e45_row0_col1" class="data row0 col1" >0.5573</td>
#       <td id="T_92e45_row0_col2" class="data row0 col2" >0.5546</td>
#       <td id="T_92e45_row0_col3" class="data row0 col3" >0.5698</td>
#       <td id="T_92e45_row0_col4" class="data row0 col4" >0.5672</td>
#       <td id="T_92e45_row0_col5" class="data row0 col5" >0.5680</td>
#       <td id="T_92e45_row0_col6" class="data row0 col6" >0.1142</td>
#       <td id="T_92e45_row0_col7" class="data row0 col7" >0.1143</td>
#       <td id="T_92e45_row0_col8" class="data row0 col8" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_92e45_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_92e45_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_92e45_row1_col1" class="data row1 col1" >0.5433</td>
#       <td id="T_92e45_row1_col2" class="data row1 col2" >0.5453</td>
#       <td id="T_92e45_row1_col3" class="data row1 col3" >0.5633</td>
#       <td id="T_92e45_row1_col4" class="data row1 col4" >0.5522</td>
#       <td id="T_92e45_row1_col5" class="data row1 col5" >0.5573</td>
#       <td id="T_92e45_row1_col6" class="data row1 col6" >0.0860</td>
#       <td id="T_92e45_row1_col7" class="data row1 col7" >0.0861</td>
#       <td id="T_92e45_row1_col8" class="data row1 col8" >0.0900</td>
#     </tr>
#     <tr>
#       <th id="T_92e45_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_92e45_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_92e45_row2_col1" class="data row2 col1" >0.5380</td>
#       <td id="T_92e45_row2_col2" class="data row2 col2" >0.5456</td>
#       <td id="T_92e45_row2_col3" class="data row2 col3" >0.5463</td>
#       <td id="T_92e45_row2_col4" class="data row2 col4" >0.5493</td>
#       <td id="T_92e45_row2_col5" class="data row2 col5" >0.5474</td>
#       <td id="T_92e45_row2_col6" class="data row2 col6" >0.0757</td>
#       <td id="T_92e45_row2_col7" class="data row2 col7" >0.0758</td>
#       <td id="T_92e45_row2_col8" class="data row2 col8" >0.0800</td>
#     </tr>
#     <tr>
#       <th id="T_92e45_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_92e45_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_92e45_row3_col1" class="data row3 col1" >0.5340</td>
#       <td id="T_92e45_row3_col2" class="data row3 col2" >0.5499</td>
#       <td id="T_92e45_row3_col3" class="data row3 col3" >0.5515</td>
#       <td id="T_92e45_row3_col4" class="data row3 col4" >0.5446</td>
#       <td id="T_92e45_row3_col5" class="data row3 col5" >0.5475</td>
#       <td id="T_92e45_row3_col6" class="data row3 col6" >0.0673</td>
#       <td id="T_92e45_row3_col7" class="data row3 col7" >0.0675</td>
#       <td id="T_92e45_row3_col8" class="data row3 col8" >0.0940</td>
#     </tr>
#     <tr>
#       <th id="T_92e45_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_92e45_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_92e45_row4_col1" class="data row4 col1" >0.5347</td>
#       <td id="T_92e45_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_92e45_row4_col3" class="data row4 col3" >0.5475</td>
#       <td id="T_92e45_row4_col4" class="data row4 col4" >0.5435</td>
#       <td id="T_92e45_row4_col5" class="data row4 col5" >0.5446</td>
#       <td id="T_92e45_row4_col6" class="data row4 col6" >0.0687</td>
#       <td id="T_92e45_row4_col7" class="data row4 col7" >0.0689</td>
#       <td id="T_92e45_row4_col8" class="data row4 col8" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_92e45_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_92e45_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_92e45_row5_col1" class="data row5 col1" >0.5320</td>
#       <td id="T_92e45_row5_col2" class="data row5 col2" >0.5287</td>
#       <td id="T_92e45_row5_col3" class="data row5 col3" >0.5567</td>
#       <td id="T_92e45_row5_col4" class="data row5 col4" >0.5410</td>
#       <td id="T_92e45_row5_col5" class="data row5 col5" >0.5480</td>
#       <td id="T_92e45_row5_col6" class="data row5 col6" >0.0629</td>
#       <td id="T_92e45_row5_col7" class="data row5 col7" >0.0632</td>

# %%
model = create_model('ada', cross_validation=False, return_train_score=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d4ee5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4ee5_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_d4ee5_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_d4ee5_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_d4ee5_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_d4ee5_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_d4ee5_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_d4ee5_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4ee5_level0_row0" class="row_heading level0 row0" >Test</th>
#       <td id="T_d4ee5_row0_col0" class="data row0 col0" >0.5273</td>
#       <td id="T_d4ee5_row0_col1" class="data row0 col1" >0.5296</td>
#       <td id="T_d4ee5_row0_col2" class="data row0 col2" >0.4524</td>
#       <td id="T_d4ee5_row0_col3" class="data row0 col3" >0.5456</td>
#       <td id="T_d4ee5_row0_col4" class="data row0 col4" >0.4947</td>
#       <td id="T_d4ee5_row0_col5" class="data row0 col5" >0.0579</td>
#       <td id="T_d4ee5_row0_col6" class="data row0 col6" >0.0588</td>
#     </tr>
#     <tr>
#       <th id="T_d4ee5_level0_row1" class="row_heading level0 row1" >Train</th>
#       <td id="T_d4ee5_row1_col0" class="data row1 col0" >0.6040</td>
#       <td id="T_d4ee5_row1_col1" class="data row1 col1" >0.6422</td>
#       <td id="T_d4ee5_row1_col2" class="data row1 col2" >0.5124</td>
#       <td id="T_d4ee5_row1_col3" class="data row1 col3" >0.6411</td>
#       <td id="T_d4ee5_row1_col4" class="data row1 col4" >0.5696</td>
#       <td id="T_d4ee5_row1_col5" class="data row1 col5" >0.2113</td>
#       <td id="T_d4ee5_row1_col6" class="data row1 col6" >0.2158</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned = tune_model(model, fold = 5, optimize = 'precision', return_train_score=True, n_iter=50)

# %%
ens_bagging = ensemble_model(model, fold = 5, method='Bagging', verbose=False)

# %%
def filtra_resultados(_df, filtro = 0):
    _df = _df[_df['prediction_label'] == 1]

    if filtro == 1:
        _df = _df[((_df['Odds'] > 1.85))]
        _df = _df[((_df['HA_Line'] <= -7)) & ((_df['HA_Line'] >= -13))]
    
    return _df

# %%
def calcula_profit(_df, stake = 1):
    _df.loc[(_df[TARGET] == 1), 'PL_BF_Predictions'] = (_df[ODDS] - 1) * stake
    _df.loc[(_df[TARGET] == 0), 'PL_BF_Predictions'] = - stake

    return _df

def exibe_metricas(_df, total, stake = 1, return_metrics = False):
    plb = _df['PL_BF_Predictions'].sum()
    entradas = _df.shape[0]
    wr = round((_df[_df[TARGET] == 1].shape[0] / entradas), 2)
    oddback = (_df[ODDS].mean())
    med_gain = _df[_df[TARGET] == 1]['PL_BF_Predictions'].mean()
    med_loss = _df[_df[TARGET] == 0]['PL_BF_Predictions'].mean()
    roi = plb / entradas
    porc_ent = entradas / total
    ev = (wr*stake*med_gain) + ((1-wr)*med_loss*stake)

    if return_metrics == False:
        print(f'PL: {plb:.2f} | ROI: {100*roi:.2f}% | Prec.: {wr:.2f}')
        print(f'Odd média: {oddback:.2f} ({1/oddback:.2f} WR)')
        print(f'Média Gain: {med_gain:.2f} | Média Loss: {med_loss:.2f}')
        print(f'EM: {ev:.2f}')
        print(f'{entradas} entradas em {total} jogos ({100*porc_ent:.2f}%)')
    else:
        return_metrics == True
        metrics = [plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev]
        return metrics

def exibe_grafico(_df):
    _df.sort_index(inplace=True)
    _df.reset_index(drop=True, inplace=True)
    _df['hbacu'] = _df['PL_BF_Predictions'].cumsum()
    _df['hbacu'].plot.line(figsize=(7,2))
    plt.show()

def treina_modelo(modelo, data):
    _df = predict_model(modelo, data, verbose = False)
    _df = _df.merge(df[[TARGET]], left_index=True, right_index=True, how='left')
    if f'{TARGET}_x' in _df.columns.tolist():
        _df.rename(columns={f'{TARGET}_x': TARGET}, inplace=True)
        _df.drop(columns=f'{TARGET}_y', inplace=True)
    
    return _df

def info_modelo(modelo, data, stake = 1, filtro = 0):
    total = data.shape[0]

    _df = treina_modelo(modelo, data)
    _df = filtra_resultados(_df, filtro=filtro)
    _df = calcula_profit(_df, stake)
    exibe_metricas(_df, total, stake)
    exibe_grafico(_df)
    
    return _df

# %%
mdl = model
flt = 1
df_tr = info_modelo(mdl, real_treino, filtro = flt)
df_teste = info_modelo(mdl, real_teste, filtro = flt)
df_comp = info_modelo(mdl, treino, filtro = flt)
# Out:
# PL: 50.21 | ROI: 22.52% | Prec.: 0.65
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.23
# 223 entradas em 1500 jogos (14.87%)
# PL: 35.67 | ROI: 15.38% | Prec.: 0.61
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.16
# 232 entradas em 1500 jogos (15.47%)
# PL: 85.88 | ROI: 18.87% | Prec.: 0.63
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.20
# 455 entradas em 3000 jogos (15.17%)

# %%
df_val = info_modelo(mdl, val, filtro = flt)
# Out:
# PL: 24.47 | ROI: 7.26% | Prec.: 0.56
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.07
# 337 entradas em 2305 jogos (14.62%)

# %%
aux_comp = treina_modelo(mdl, treino)
aux_comp = filtra_resultados(aux_comp, filtro = flt)
plt.axvline(x=len(aux_comp), color='red', linestyle='--')
df_completo = info_modelo(mdl, pd.concat([treino, val1, val2]), filtro = flt)
# Out:
# PL: 110.35 | ROI: 13.93% | Prec.: 0.60
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.14
# 792 entradas em 5305 jogos (14.93%)

# %% [markdown]
# # Comparação de modelos

# %% [markdown]
# ### Escolhendo os modelos

# %%
FILTRO = 1
CONJUNTO = 'val'

for i in range(14):
    try:
        if CONJUNTO != 'teste':
            print(f'{top[i].__class__.__name__} (i = {i})\n')
            aux_tr = treina_modelo(top[i], real_teste)
            aux_tr = filtra_resultados(aux_tr, filtro = FILTRO)
            plt.axvline(x=len(aux_tr), color='red', linestyle='--')
            aux_total = treina_modelo(top[i], val1)
            aux_total = filtra_resultados(aux_total, filtro = FILTRO)
            plt.axvline(x=len(aux_total) + len(aux_tr), color='blue', linestyle='--')
            aux = info_modelo(top[i], pd.concat([real_teste, val1, val2]), filtro = FILTRO)
        else:
            print(f'{top[i].__class__.__name__} (i = {i})\n')
            aux = info_modelo(top[i], real_teste, filtro = FILTRO)
    except:
        print(f'O modelo apresentou um erro.\n')
        pass
# Out:
# DecisionTreeClassifier (i = 0)
#
# PL: 47.17 | ROI: 9.18% | Prec.: 0.57
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.08
# 514 entradas em 3805 jogos (13.51%)
# RandomForestClassifier (i = 1)
#
# PL: 44.04 | ROI: 8.52% | Prec.: 0.57
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.08
# 517 entradas em 3805 jogos (13.59%)
# XGBClassifier (i = 2)
#
# PL: 49.02 | ROI: 9.43% | Prec.: 0.57
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.08
# 520 entradas em 3805 jogos (13.67%)
# LGBMClassifier (i = 3)
#
# PL: 60.71 | ROI: 10.96% | Prec.: 0.58
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.10
# 554 entradas em 3805 jogos (14.56%)
# RidgeClassifier (i = 4)
#
# PL: 42.41 | ROI: 5.01% | Prec.: 0.55
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.05
# 846 entradas em 3805 jogos (22.23%)
# LogisticRegression (i = 5)
#
# PL: 47.46 | ROI: 5.51% | Prec.: 0.55
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.05
# 862 entradas em 3805 jogos (22.65%)
# ExtraTreesClassifier (i = 6)
#
# PL: 39.97 | ROI: 8.14% | Prec.: 0.57
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.08
# 491 entradas em 3805 jogos (12.90%)
# KNeighborsClassifier (i = 7)
#
# PL: 47.67 | ROI: 8.16% | Prec.: 0.57
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.08
# 584 entradas em 3805 jogos (15.35%)
# LinearDiscriminantAnalysis (i = 8)
#
# PL: 38.83 | ROI: 4.84% | Prec.: 0.55
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.05
# 802 entradas em 3805 jogos (21.08%)
# GaussianNB (i = 9)
#
# PL: 45.00 | ROI: 5.14% | Prec.: 0.55
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.05
# 876 entradas em 3805 jogos (23.02%)
# AdaBoostClassifier (i = 10)
#
# PL: 60.14 | ROI: 10.57% | Prec.: 0.58
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.10
# 569 entradas em 3805 jogos (14.95%)
# GradientBoostingClassifier (i = 11)
#
# PL: 57.11 | ROI: 9.18% | Prec.: 0.57
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.08
# 622 entradas em 3805 jogos (16.35%)
# SGDClassifier (i = 12)
#
# PL: 47.71 | ROI: 5.43% | Prec.: 0.55
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.05
# 879 entradas em 3805 jogos (23.10%)
# QuadraticDiscriminantAnalysis (i = 13)
#
# O modelo apresentou um erro.

# %%
blended18 = blend_models(estimator_list = [top[1], top[8]], fold = 5, verbose=False)

# %%
model_list = [top[1], top[8], blended18]

# %% [markdown]
# ### Resultados

# %%
FILTRO = 2

for item in model_list:
    try:
        print(f'{item.__class__.__name__}\n')
        aux_tr = treina_modelo(item, real_teste)
        aux_tr = filtra_resultados(aux_tr, filtro = FILTRO)
        plt.axvline(x=len(aux_tr), color='red', linestyle='--')
        aux_total = treina_modelo(item, val1)
        aux_total = filtra_resultados(aux_total, filtro = FILTRO)
        plt.axvline(x=len(aux_total) + len(aux_tr), color='blue', linestyle='--')
        aux = info_modelo(item, pd.concat([real_teste, val]), filtro = FILTRO)
    except:
        print(f'O modelo apresentou um erro.\n')
        pass
# Out:
# GaussianNB
#
# PL: 26.46 | ROI: 11.92% | Prec.: 0.54
# Odd média: 2.11 (0.47 WR)
# Média Gain: 1.07 | Média Loss: -1.00
# EM: 0.12
# 222 entradas em 1637 jogos (13.56%)
# KNeighborsClassifier
#
# PL: 19.83 | ROI: 11.53% | Prec.: 0.53
# Odd média: 2.14 (0.47 WR)
# Média Gain: 1.11 | Média Loss: -1.00
# EM: 0.12
# 172 entradas em 1637 jogos (10.51%)
# VotingClassifier
#
# PL: 19.81 | ROI: 9.43% | Prec.: 0.53
# Odd média: 2.10 (0.48 WR)
# Média Gain: 1.05 | Média Loss: -1.00
# EM: 0.09
# 210 entradas em 1637 jogos (12.83%)

# %% [markdown]
# # Script qcut

# %%
# df_cut1 = df_treino.copy()
df_cut = df_teste.copy()
# df_cut = pd.concat([df_cut1, df_cut2])

# %%
variaveis = features.copy()
variaveis.append('prediction_score')

for var in variaveis:
    try:
        nome = f'Cat_{var}'
        # Usa qcut para definir os grupos
        df_cut[nome]  = pd.qcut(df_cut[var], q = 10, duplicates='drop')

        target = 'PL_BF_Predictions'
        pivot_table = pd.pivot_table(df_cut,
                                    values=target,
                                    index=[nome],
                                    aggfunc=['sum', 'count']
                                    )
        

        pivot_table['ratio'] = pivot_table[('sum', target)] / pivot_table[('count', target)]

        aux_treino = pivot_table[pivot_table['ratio'] != 0]


        print(var)
        print(aux_treino)
        print()
        print('\n\n')
        print('------------------------------------------------')
        print('\n\n')
    except:
        pass
# Out:
# Odds_H
#                                         sum             count     ratio
#                           PL_BF_Predictions PL_BF_Predictions
# Cat_Odds_H
# (1.0190000000000001, 1.1]             -7.40                36 -0.205556
# (1.1, 1.14]                            3.70                21  0.176190
# (1.14, 1.2]                           16.25                37  0.439189
# (1.2, 1.25]                            6.91                33  0.209394
# (1.25, 1.26]                          -2.55                14 -0.182143
# (1.26, 1.28]                          -6.27                29 -0.216207
# (1.28, 1.31]                           8.96                31  0.289032
# (1.31, 1.33]                           4.26                28  0.152143
# (1.33, 1.37]                           5.18                27  0.191852
# (1.37, 2.15]                          11.16                23  0.485217
#
#
#
#
# ------------------------------------------------
#
#
#
# Odds_Over
#                                         sum             count     ratio
#                           PL_BF_Predictions PL_BF_Predictions
# Cat_Odds_Over
# (1.8290000000000002, 1.9]         40.299995               277  0.145487
# (1.9, 1.95]                       -0.100000                 2 -0.050000
#
#
#
#
# ------------------------------------------------
#
#
#
# Odds_Under
#                                         sum             count     ratio
#                           PL_BF_Predictions PL_BF_Predictions
# Cat_Odds_Under
# (1.8290000000000002, 1.9]         35.899998               270  0.132963
# (1.9, 2.0]                         4.300000                 9  0.477778
#
#
#
#
# ------------------------------------------------
#
#
#
# Over_Line
#                                sum             count     ratio
#                  PL_BF_Predictions PL_BF_Predictions
# Cat_Over_Line
# (201.499, 210.5]         13.299999                36  0.369444
# (210.5, 213.5]            3.600000                23  0.156522
# (213.5, 216.5]            8.559999                37  0.231351
# (216.5, 218.5]            8.200000                26  0.315385
# (218.5, 220.5]           -4.400001                31 -0.141936
# (220.5, 222.5]           -3.900000                21 -0.185714
# (222.5, 224.5]            1.550000                27  0.057407
# (224.5, 225.5]            5.610000                23  0.243913
# (225.5, 229.5]            5.970000                32  0.186562
# (229.5, 245.5]            1.710000                23  0.074348
#
#
#
#
# ------------------------------------------------
#
#
#
# HA_Line
#                                sum             count     ratio
#                  PL_BF_Predictions PL_BF_Predictions
# Cat_HA_Line
# (-18.501, -13.5]         -2.540000                33 -0.076970
# (-13.5, -11.5]            7.599999                38  0.200000
# (-11.5, -10.5]            2.100000                15  0.140000
# (-10.5, -9.5]             9.209999                44  0.209318
# (-9.5, -8.5]             11.919999                66  0.180606
# (-8.5, -7.5]             11.909999                83  0.143494
#
#
#
#
# ------------------------------------------------
#
#
#
# P(A)
#                               sum             count     ratio
#                 PL_BF_Predictions PL_BF_Predictions
# Cat_P(A)
# (0.0578, 0.133]         -5.400000                34 -0.158824
# (0.133, 0.174]           9.700000                34  0.285294
# (0.174, 0.211]           7.349999                25  0.294000
# (0.211, 0.238]           4.460000                24  0.185833
# (0.238, 0.25]            0.800000                24  0.033333
# (0.25, 0.267]           -6.270000                29 -0.216207
# (0.267, 0.278]           8.059999                30  0.268667
# (0.278, 0.294]           4.300000                28  0.153571
# (0.294, 0.312]           7.040000                27  0.260741
# (0.312, 0.575]          10.160000                24  0.423333
#
#
#
#
# ------------------------------------------------
#
#
#
# P(O)
#                              sum             count     ratio
#                PL_BF_Predictions PL_BF_Predictions
# Cat_P(O)
# (0.512, 0.526]         36.899998               269  0.137175
# (0.526, 0.546]          3.300000                10  0.330000
#
#
#
#
# ------------------------------------------------
#
#
#
# P(U)
#                              sum             count     ratio
#                PL_BF_Predictions PL_BF_Predictions
# Cat_P(U)
# (0.499, 0.526]         39.639996               272  0.145735
# (0.526, 0.546]          0.560000                 7  0.080000
#
#
#
#
# ------------------------------------------------
#
#
#
# P_Diff
#                                sum             count     ratio
#                  PL_BF_Predictions PL_BF_Predictions
# Cat_P_Diff
# (0.0288, 0.0398]         16.619999                29  0.573103
# (0.0398, 0.0422]          2.410000                28  0.086071
# (0.0422, 0.0426]         -2.340000                27 -0.086667
# (0.0426, 0.0435]         12.559999                33  0.380606
# (0.0435, 0.0438]         -0.450000                29 -0.015517
# (0.0438, 0.0439]          5.349999                27  0.198148
# (0.0439, 0.0448]          5.510000                23  0.239565
# (0.0448, 0.046]           1.950000                38  0.051316
# (0.046, 0.0483]          -3.040000                22 -0.138182
# (0.0483, 0.0549]          1.630000                23  0.070870
#
#
#
#
# ------------------------------------------------
#
#
#
# CV_ML
#                              sum             count     ratio
#                PL_BF_Predictions PL_BF_Predictions
# Cat_CV_ML
# (0.124, 0.566]         15.320000                34  0.450588
# (0.566, 0.619]          1.780000                38  0.046842
# (0.619, 0.66]           5.610000                21  0.267143
# (0.66, 0.694]           4.510000                24  0.187917
# (0.694, 0.737]         -6.480000                35 -0.185143
# (0.737, 0.765]          3.910000                17  0.230000
# (0.765, 0.844]          8.049999                30  0.268333
# (0.844, 0.946]         11.099999                25  0.444000
# (0.946, 1.052]         -2.500000                31 -0.080645
# (1.052, 1.254]         -1.100000                24 -0.045833
#
#
#
#
# ------------------------------------------------
#
#
#
# CV_Over
#                                sum             count     ratio
#                  PL_BF_Predictions PL_BF_Predictions
# Cat_CV_Over
# (-0.001, 0.0628]         40.199997               279  0.144086
#
#
#
#
# ------------------------------------------------
#
#
#
# Odds
#                                         sum             count     ratio
#                           PL_BF_Predictions PL_BF_Predictions
# Cat_Odds
# (1.8590000000000002, 1.9]         40.599998               263  0.154373
# (1.9, 1.95]                       -0.400000                16 -0.025000
#
#
#
#
# ------------------------------------------------
#
#
#
# prediction_score
#                                    sum             count     ratio
#                      PL_BF_Predictions PL_BF_Predictions
# Cat_prediction_score
# (0.499, 0.521]                4.349999                28  0.155357
# (0.521, 0.538]               -3.250000                28 -0.116071
# (0.538, 0.568]                6.210000                28  0.221786
# (0.568, 0.584]                4.260000                28  0.152143
# (0.584, 0.601]                4.270000                28  0.152500
# (0.601, 0.613]               -0.390000                27 -0.014444
# (0.613, 0.632]                6.170000                28  0.220357
# (0.632, 0.66]                 2.400000                28  0.085714
# (0.66, 0.683]                13.860000                28  0.495000
# (0.683, 0.85]                 2.320000                28  0.082857
#
#
#
#
# ------------------------------------------------

# %%
_df = _df[((_df['Avg_Retornos_BH'] >= -0.35) & (_df['Avg_Retornos_BH'] < 0.35)) | ((_df['Avg_Retornos_BH'] >= 3.7) & (_df['Avg_Retornos_BH'] < 5))]

_df = _df[((_df['Over_Line'] < 218) | (_df['Over_Line'] > 223))]

# %%
# display(df_cut2.groupby('Cat_DP_Odds_Geral_H')['DP_Odds_Geral_H'].describe())

# %% [markdown]
# # Script variáveis

# %%
colunas = ['Odds_H', 'Odds_A', 'Over_Line', 'Odds_Over', 'Odds_Under', 'HA_Line',
       'HA_Odds_H', 'HA_Odds_A', 'P(H)', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'Porc_Over_Home',
       'Porc_Over_Away', 'Avg_CG_H', 'DP_CG_H',
       'CV_CG_H', 'Avg_CG_A', 'DP_CG_A', 'CV_CG_A', 'MediaCustoGolHome',
       'MediaCustoGolAway', 'Last_CG_H', 'Last_CG_A', 'Acima_Last_CG_H',
       'Acima_Last_CG_A', 'Abaixo_Last_CG_H', 'Abaixo_Last_CG_A', 'CV_ML',
       'CV_Over', 'CV_HA', 'Retornos_BH_Acu', 'Avg_Retornos_BH', 'Custo_Retorno_BH',
       'Avg_Porc_BH_Bookie', 'Avg_Porc_BH_Real', 'Dist_Porc_BH',
       'Retornos_BA_Acu', 'Avg_Retornos_BA', 'Custo_Retorno_BA',
       'Avg_Porc_BA_Bookie', 'Avg_Porc_BA_Real', 'Dist_Porc_BA']

colunas = ['Odds_H', 'Odds_A', 'Odds_Over', 'Odds_Under', 'Over_Line',  'HA_Line', 'HA_Odds_H', 'HA_Odds_A', 'P(H)', 'P(A)', 
       'P(O)', 'P(U)', 'P_Diff', 'CV_ML',
       'CV_Over', 'CV_HA']

# %%
import random

def pegar_elementos_aleatorios(lista):
    # Gerar um número aleatório entre 2 e 7
    num_elementos = random.randint(5, 12)

    # Garantir que o número de elementos não ultrapasse o tamanho da lista
    num_elementos = min(num_elementos, len(lista))

    # Selecionar elementos aleatórios da lista
    elementos_aleatorios = random.sample(lista, num_elementos)

    return elementos_aleatorios

# %%
def cria_modelo(fts, _seed = 2023, _filtro = 0):
        try:
                cria_setup(features=fts, seed = _seed)

                model = create_model('lr', verbose = False, fold = 5)
                tab = pull()
                prec_model = (tab.loc['Mean', 'Prec.'])
                previsoes = predict_model(model, verbose = False)

                stake = 1

                total = previsoes.shape[0]

                previsoes = previsoes[previsoes['prediction_label'] == 1]
                previsoes = filtra_resultados(previsoes, filtro = _filtro)

                previsoes.loc[(previsoes[TARGET] == 1), 'PL_BF_Predictions'] = (previsoes[ODDS] - 1) * stake
                previsoes.loc[(previsoes[TARGET] == 0), 'PL_BF_Predictions'] = - stake

                plb = previsoes['PL_BF_Predictions'].sum()
                entradas = previsoes.shape[0]
                wr = round((previsoes[previsoes[TARGET] == 1].shape[0] / entradas), 2)
                oddback = previsoes[previsoes['prediction_label'] == 1][ODDS].mean()
                med_gain = previsoes[previsoes[TARGET] == 1]['PL_BF_Predictions'].mean()
                med_loss = previsoes[previsoes[TARGET] == 0]['PL_BF_Predictions'].mean()
                roi = plb / entradas
                porc_ent = entradas / total
                ev = (wr*stake*med_gain) + ((1-wr)*med_loss*stake)

                metrics = [prec_model, plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev]

                return metrics
        except Exception as e:
                print(e)
                return [0, 0, 0, 0, 0, 0, 0, 0, 0]

# %%
melhor_PL = -10000

for i in range(20):
    feats = pegar_elementos_aleatorios(colunas)
    feats.append(ODDS)

    metrics = cria_modelo(fts=feats)
    prec_model, plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev = metrics
            
    print(f'Rodada {i+1}')
    if plb > melhor_PL:
        melhor_PL = plb
        print(f'**Novo melhor**')
        print(f'Precision: {prec_model:.4f}')
        print(f'PL: {plb:.2f} | ROI: {100*roi:.2f}% | EM: {ev:.2f} | Prec.: {wr:.2f} | Entradas: {porc_ent:.2f}')
        print(f'features = {feats}\n')
    print()
# Out:
# Rodada 1
# **Novo melhor**
# Precision: 0.4040
# PL: -57.26 | ROI: -15.73% | EM: -0.16 | Prec.: 0.38 | Entradas: 0.49
# features = ['Over_Line', 'CV_ML', 'Odds_Under', 'HA_Odds_A', 'P(U)', 'P_Diff', 'CV_Over', 'P(H)', 'Odds']
#
#
# Rodada 2
# **Novo melhor**
# Precision: 0.4094
# PL: -50.24 | ROI: -14.78% | EM: -0.16 | Prec.: 0.39 | Entradas: 0.46
# features = ['HA_Line', 'Odds_H', 'P(H)', 'P_Diff', 'Odds_Over', 'CV_HA', 'P(U)', 'CV_Over', 'P(A)', 'CV_ML', 'Odds']
#
#
# Rodada 3
#
# Rodada 4
# **Novo melhor**
# Precision: 0.4263
# PL: -48.52 | ROI: -13.86% | EM: -0.14 | Prec.: 0.39 | Entradas: 0.47
# features = ['HA_Line', 'P(O)', 'CV_Over', 'P(H)', 'Over_Line', 'Odds']
#
#
# Rodada 5
#
# Rodada 6
# **Novo melhor**
# Precision: 0.4068
# PL: -47.08 | ROI: -12.93% | EM: -0.14 | Prec.: 0.39 | Entradas: 0.49
# features = ['Odds_Over', 'HA_Odds_H', 'Odds_A', 'P(H)', 'HA_Odds_A', 'Odds_Under', 'CV_Over', 'CV_ML', 'Over_Line', 'P_Diff', 'P(A)', 'P(O)', 'Odds']
#
#
# Rodada 7
#
# Rodada 8
#
# Rodada 9
# **Novo melhor**
# Precision: 0.3952
# PL: -46.74 | ROI: -12.46% | EM: -0.12 | Prec.: 0.40 | Entradas: 0.50
# features = ['Odds_H', 'HA_Odds_A', 'Odds_Over', 'P_Diff', 'P(A)', 'CV_ML', 'Odds_A', 'P(H)', 'CV_Over', 'Odds']
#
#
# Rodada 10
#
# Rodada 11
#
# Rodada 12
#
# Rodada 13
#
# Rodada 14
# **Novo melhor**
# Precision: 0.4017
# PL: -41.09 | ROI: -11.11% | EM: -0.12 | Prec.: 0.40 | Entradas: 0.50
# features = ['HA_Line', 'P(O)', 'CV_Over', 'CV_ML', 'HA_Odds_H', 'P(U)', 'Odds_A', 'Odds_H', 'P_Diff', 'Odds']
#
#
# Rodada 15
#
# Rodada 16
#
# Rodada 17
#
# Rodada 18
#
# Rodada 19
#
# Rodada 20

# %% [markdown]
# # Segundo filtro

# %%
fits = ['Odds_H', 'Odds_A', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line',  'P(H)', 'P(A)', 
       'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'CV_HA', ODDS]

fits = ['Odds_H', 'Odds_A', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(H)', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']

fits = ['Odds_H', 'Odds_A', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']

fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']

# %%
metrics = cria_modelo(fits)
prec_model, plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev = metrics

print('---------------------- BASE ----------------------')
print(f'Precision: {prec_model:.4f}')
print(f'PL: {plb:.2f} | ROI: {100*roi:.2f}% | EM: {ev:.2f} | Prec.: {wr:.2f} | Entradas: {porc_ent:.2f}')
print(f'fits = {fits}\n')
print('--------------------------------------------------')
melhor_PL = plb

for i in range(len(fits) - 1):
    feat = fits[i]
    fits.pop(i)
    print(f'Removido: {feat}')

    metrics = cria_modelo(fits)
    prec_model, plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev = metrics

    if plb >= melhor_PL:
        print('*** NOVO MELHOR ***')
        melhor_PL = plb
    print(f'Precision: {prec_model:.4f}')
    print(f'PL: {plb:.2f} | ROI: {100*roi:.2f}% | EM: {ev:.2f} | Prec.: {wr:.2f} | Entradas: {porc_ent:.2f}')
    print(f'fits = {fits}\n')
    fits.insert(i, feat)
    print()
# Out:
# ---------------------- BASE ----------------------
# Precision: 0.5410
# PL: 33.76 | ROI: 3.96% | EM: 0.04 | Prec.: 0.55 | Entradas: 0.57
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
# --------------------------------------------------
# Removido: Odds_H
# Precision: 0.5359
# PL: 16.31 | ROI: 1.87% | EM: 0.02 | Prec.: 0.54 | Entradas: 0.58
# fits = ['Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: Odds_Over
# Precision: 0.5337
# PL: 31.23 | ROI: 3.58% | EM: 0.04 | Prec.: 0.55 | Entradas: 0.58
# fits = ['Odds_H', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: Odds_Under
# Precision: 0.5357
# PL: 30.56 | ROI: 3.70% | EM: 0.04 | Prec.: 0.55 | Entradas: 0.55
# fits = ['Odds_H', 'Odds_Over', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: Over_Line
# Precision: 0.5301
# PL: 31.81 | ROI: 3.65% | EM: 0.04 | Prec.: 0.55 | Entradas: 0.58
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: HA_Line
# Precision: 0.5254
# PL: 8.88 | ROI: 1.02% | EM: 0.00 | Prec.: 0.53 | Entradas: 0.58
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: P(A)
# Precision: 0.5348
# PL: 28.25 | ROI: 3.26% | EM: 0.04 | Prec.: 0.55 | Entradas: 0.58
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: P(O)
# Precision: 0.5351
# PL: 31.98 | ROI: 3.84% | EM: 0.04 | Prec.: 0.55 | Entradas: 0.55
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: P(U)
# Precision: 0.5347
# PL: 26.23 | ROI: 3.07% | EM: 0.02 | Prec.: 0.54 | Entradas: 0.57
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: P_Diff
# Precision: 0.5310
# PL: 16.02 | ROI: 1.87% | EM: 0.02 | Prec.: 0.54 | Entradas: 0.57
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: CV_ML
# *** NOVO MELHOR ***
# Precision: 0.5395
# PL: 34.00 | ROI: 4.29% | EM: 0.04 | Prec.: 0.55 | Entradas: 0.53
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_Over', 'Odds']
#
#
# Removido: CV_Over
# Precision: 0.5439
# PL: 15.86 | ROI: 1.84% | EM: 0.02 | Prec.: 0.54 | Entradas: 0.58
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'Odds']

# %% [markdown]
# # Cross validation

# %%
ftrs = ['Avg_Porc_BA_Real', 'P(A)', 'P(O)', 'MediaCustoGolAway', 'HA_Odds_H', 'CV_Over', 'Retornos_BH_Acu', 'P(U)', 'Avg_Porc_BA_Bookie', 'DP_CG_H', 'Retornos_BA_Acu', 'Last_CG_H', 'Porc_Over_Away', 'Avg_Porc_BH_Real', 'CV_CG_H', 'Odds']

# %%
results = []
seeds = random.sample(range(0, 9999), 10)

for i in range(len(seeds)):

        cria_setup(seed=seeds[i], features=ftrs)

        cross_model = create_model('lr', verbose = False, cross_validation=False)
        
        previsoes = predict_model(cross_model, real_teste, verbose = False)
        previsoes = previsoes.merge(df[ODDS], left_index=True, right_index=True, how='left')
        if f'{ODDS}_x' in previsoes.columns.tolist():
                previsoes.rename(columns={f'{ODDS}_x': ODDS}, inplace=True)
                previsoes.drop(columns=f'{ODDS}_y', inplace=True)

        stake = 1

        total = previsoes.shape[0]

        previsoes = previsoes[(previsoes['prediction_label'] == 1)]

        previsoes.loc[(previsoes[TARGET] == 1), 'PL_BF_Predictions'] = (previsoes[ODDS] - 1) * stake
        previsoes.loc[(previsoes[TARGET] == 0), 'PL_BF_Predictions'] = - stake

        ############ Filtro ############
        previsoes = filtra_resultados(previsoes, filtro = 0)
        previsoes = calcula_profit(previsoes)
        metrics = exibe_metricas(previsoes, total = total, return_metrics=True)
        plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev = metrics
        
        results.append(wr)

        print(f'Fold {i+1} (seed {seeds[i]})')
        print(f'PL: {plb:.2f} | ROI: {100*roi:.2f}% | EM: {ev:.2f} | Prec.: {wr:.2f} | Entradas: {porc_ent:.2f}')
        print()

print(f'Média: {np.mean(results):.2f} | DP: {np.std(results):.2f}')
# Out:
# Fold 1 (seed 9839)
# PL: -1.70 | ROI: -0.67% | EM: -0.01 | Prec.: 0.64 | Entradas: 0.51
#
# Fold 2 (seed 457)
# PL: -10.97 | ROI: -4.27% | EM: -0.04 | Prec.: 0.62 | Entradas: 0.51
#
# Fold 3 (seed 5673)
# PL: -7.25 | ROI: -2.70% | EM: -0.03 | Prec.: 0.63 | Entradas: 0.54
#
# Fold 4 (seed 2960)
# PL: -6.15 | ROI: -2.44% | EM: -0.03 | Prec.: 0.63 | Entradas: 0.50
#
# Fold 5 (seed 4170)
# PL: -0.36 | ROI: -0.14% | EM: -0.00 | Prec.: 0.64 | Entradas: 0.52
#
# Fold 6 (seed 2715)
# PL: -2.58 | ROI: -0.98% | EM: -0.02 | Prec.: 0.63 | Entradas: 0.53
#
# Fold 7 (seed 4190)
# PL: -2.06 | ROI: -0.89% | EM: -0.01 | Prec.: 0.64 | Entradas: 0.46
#
# Fold 8 (seed 1100)
# PL: -2.54 | ROI: -1.06% | EM: -0.01 | Prec.: 0.64 | Entradas: 0.48
#
# Fold 9 (seed 4678)
# PL: -6.83 | ROI: -2.71% | EM: -0.03 | Prec.: 0.63 | Entradas: 0.50
#
# Fold 10 (seed 2480)
# PL: -10.90 | ROI: -4.31% | EM: -0.04 | Prec.: 0.62 | Entradas: 0.51
#
# Média: 0.63 | DP: 0.01

# %% [markdown]
# # Entradas Aleatórias

# %%
def new_random_model(_val, _n):

    for i in range(_n):
        random_df = _val.copy()
        random_df['Entrada'] = [random.choice([0, 1]) for _ in range(len(random_df))]

        random_df = random_df[random_df['Entrada'] == 1]
        random_df.loc[(random_df[TARGET] == 1), 'PL'] = (random_df[ODDS] - 1)
        random_df.loc[(random_df[TARGET] == 0), 'PL'] = - 1
        
        random_df.sort_values('Date', inplace=True)
        random_df.reset_index(drop=True, inplace=True)
        random_df['hbacu'] = random_df['PL'].cumsum()
        random_df['hbacu'].plot.line(figsize=(12,6))
    
    plt.show()

# %%
new_random_model(val, 100)
