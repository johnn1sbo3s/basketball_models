# %%
import pandas as pd; pd.set_option('display.max_columns', None)
import numpy as np
import random
import matplotlib.pyplot as plt
from pycaret.classification import *

import sys
sys.path.append('../../../scripts/')
from PreparaDataset import *

# %% [markdown]
# # Parâmetros do método

# %%
TARGET = 'Back_HA_Zebra'
ODDS = 'Odds'

# %% [markdown]
# # Carregando o dataset

# %%
data = pd.read_csv('../../../data/Entire_Season.csv')

# %%
def prepara_dataset(_df):
    # HA
    _df.loc[(_df['Back_HA_H']) == 0, 'Back_HA_A'] = 1
    _df.loc[(_df['Back_HA_H']) == 1, 'Back_HA_A'] = 0
    _df.loc[(_df['Back_HA_H']) == 2, 'Back_HA_A'] = 2

    _df.loc[(_df['HA_Line']) > 0, 'Zebra'] = 'Casa'
    _df.loc[(_df['HA_Line']) < 0, 'Zebra'] = 'Fora'
    _df['Zebra'] = _df['Zebra'].astype('category')

    # Odds
    _df.loc[(_df['Zebra']) == 'Casa', 'Odds'] = _df['HA_Odds_H']
    _df.loc[(_df['Zebra']) == 'Fora', 'Odds'] = _df['HA_Odds_A']

    _df.loc[((_df['Zebra'] == 'Casa') & (_df['Back_HA_H'] == 1)), 'Back_HA_Zebra'] = 1
    _df.loc[((_df['Zebra'] == 'Casa') & (_df['Back_HA_H'] == 0)), 'Back_HA_Zebra'] = 0
    _df.loc[((_df['Zebra'] == 'Fora') & (_df['Back_HA_A'] == 1)), 'Back_HA_Zebra'] = 1
    _df.loc[((_df['Zebra'] == 'Fora') & (_df['Back_HA_A'] == 0)), 'Back_HA_Zebra'] = 0

    _df.reset_index(drop=True, inplace=True)

    # Limpa _df
    _df.replace([np.inf, -np.inf], 0, inplace=True)
    _df.dropna(subset=[TARGET], inplace=True)
    # _df = _df[(_df['Avg_CG_H'] != 0) & (_df['Avg_CG_A'] != 0) & (_df['DP_CG_H'] != 0) & (_df['DP_CG_A'] != 0) & (_df['MediaCustoGolAway'] != 0)]
    
    return _df

# %%
df = prepara_df(data)
df = prepara_dataset(df)

# %%
# TRAIN_SIZE = 0.625
# div = int(TRAIN_SIZE * len(df))

div = 3000
treino = df.iloc[:div, :]
val = df.iloc[div: , :]

print(f'Treino: {treino.shape[0]} | Validação: {val.shape[0]}')
print(f"Odd média: {treino[ODDS].mean():.2f}")
print(f"WR: {treino[TARGET].mean():.2f} (Odd justa: {1 / treino[TARGET].mean():.2f})")
# Out:
# Treino: 3000 | Validação: 2305
# Odd média: 1.90
# WR: 0.51 (Odd justa: 1.96)

# %% [markdown]
# # Validação 2

# %%
val1 = val[val['Date'] < '2023-10-20']
val2 = val[val['Date'] > '2023-10-19']

print(f'Validação 1: {val1.shape[0]} | Validação 2: {val2.shape[0]}')
# Out:
# Validação 1: 2146 | Validação 2: 159

# %% [markdown]
# # Criação do modelo

# %%
features = ['Odds_H', 'Odds_A', 'Over_Line', 'Odds_Over', 'Odds_Under', 'HA_Line',
       'HA_Odds_H', 'HA_Odds_A', 'P(H)', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'Porc_Over_Home',
       'Porc_Over_Away', 'Avg_CG_H', 'DP_CG_H',
       'CV_CG_H', 'Avg_CG_A', 'DP_CG_A', 'CV_CG_A', 'MediaCustoGolHome',
       'MediaCustoGolAway', 'Last_CG_H', 'Last_CG_A', 'Acima_Last_CG_H',
       'Acima_Last_CG_A', 'Abaixo_Last_CG_H', 'Abaixo_Last_CG_A', 'CV_ML',
       'CV_Over', 'CV_HA', 'Retornos_BH_Acu', 'Avg_Retornos_BH', 'Custo_Retorno_BH',
       'Avg_Porc_BH_Bookie', 'Avg_Porc_BH_Real', 'Dist_Porc_BH',
       'Retornos_BA_Acu', 'Avg_Retornos_BA', 'Custo_Retorno_BA',
       'Avg_Porc_BA_Bookie', 'Avg_Porc_BA_Real', 'Dist_Porc_BA', ODDS]

features = ['Odds_H', 'Odds_A', 'Odds_Over', 'Odds_Under', 'Over_Line',  'HA_Line', 'HA_Odds_H', 'HA_Odds_A', 'P(H)', 'P(A)', 
       'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'CV_HA', ODDS]

features = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']

# %%
def cria_setup(seed = 2023, features = features):
    cls = setup(data = treino,
            ignore_features = [x for x in treino.columns.to_list() if x not in features and x != TARGET],
            target = TARGET,
            train_size = 0.5,
            normalize = True,
            normalize_method = 'zscore',
            session_id = seed,
            remove_outliers = True,
            fix_imbalance = True,
            verbose = False
            )

# %%
cria_setup(seed = 2023, features = features)

xtrain_treino = get_config('X_train')
ytrain_treino = get_config('y_train')
xtrain_teste = get_config('X_test')
ytrain_teste = get_config('y_test')

real_treino = pd.concat([xtrain_treino, ytrain_treino], axis=1)
real_teste = pd.concat([xtrain_teste, ytrain_teste],  axis=1)

# %%
top = compare_models(exclude=['catboost', 'dummy'], fold = 5, sort='precision', n_select=14)
# Out:
# <style type="text/css">
# #T_ff4e9 th {
#   text-align: left;
# }
# #T_ff4e9_row0_col0, #T_ff4e9_row1_col0, #T_ff4e9_row1_col1, #T_ff4e9_row1_col2, #T_ff4e9_row1_col3, #T_ff4e9_row1_col4, #T_ff4e9_row1_col5, #T_ff4e9_row1_col6, #T_ff4e9_row1_col7, #T_ff4e9_row2_col0, #T_ff4e9_row2_col1, #T_ff4e9_row2_col2, #T_ff4e9_row2_col3, #T_ff4e9_row2_col4, #T_ff4e9_row2_col5, #T_ff4e9_row2_col6, #T_ff4e9_row2_col7, #T_ff4e9_row3_col0, #T_ff4e9_row3_col1, #T_ff4e9_row3_col2, #T_ff4e9_row3_col3, #T_ff4e9_row3_col4, #T_ff4e9_row3_col5, #T_ff4e9_row3_col6, #T_ff4e9_row3_col7, #T_ff4e9_row4_col0, #T_ff4e9_row4_col1, #T_ff4e9_row4_col2, #T_ff4e9_row4_col3, #T_ff4e9_row4_col4, #T_ff4e9_row4_col5, #T_ff4e9_row4_col6, #T_ff4e9_row4_col7, #T_ff4e9_row5_col0, #T_ff4e9_row5_col1, #T_ff4e9_row5_col2, #T_ff4e9_row5_col3, #T_ff4e9_row5_col4, #T_ff4e9_row5_col5, #T_ff4e9_row5_col6, #T_ff4e9_row5_col7, #T_ff4e9_row6_col0, #T_ff4e9_row6_col1, #T_ff4e9_row6_col2, #T_ff4e9_row6_col3, #T_ff4e9_row6_col4, #T_ff4e9_row6_col5, #T_ff4e9_row6_col6, #T_ff4e9_row6_col7, #T_ff4e9_row7_col0, #T_ff4e9_row7_col1, #T_ff4e9_row7_col2, #T_ff4e9_row7_col3, #T_ff4e9_row7_col4, #T_ff4e9_row7_col5, #T_ff4e9_row7_col6, #T_ff4e9_row7_col7, #T_ff4e9_row8_col0, #T_ff4e9_row8_col1, #T_ff4e9_row8_col2, #T_ff4e9_row8_col3, #T_ff4e9_row8_col4, #T_ff4e9_row8_col5, #T_ff4e9_row8_col6, #T_ff4e9_row8_col7, #T_ff4e9_row9_col0, #T_ff4e9_row9_col1, #T_ff4e9_row9_col2, #T_ff4e9_row9_col3, #T_ff4e9_row9_col4, #T_ff4e9_row9_col5, #T_ff4e9_row9_col6, #T_ff4e9_row9_col7, #T_ff4e9_row10_col0, #T_ff4e9_row10_col1, #T_ff4e9_row10_col2, #T_ff4e9_row10_col3, #T_ff4e9_row10_col4, #T_ff4e9_row10_col5, #T_ff4e9_row10_col6, #T_ff4e9_row10_col7, #T_ff4e9_row11_col0, #T_ff4e9_row11_col1, #T_ff4e9_row11_col2, #T_ff4e9_row11_col3, #T_ff4e9_row11_col4, #T_ff4e9_row11_col5, #T_ff4e9_row11_col6, #T_ff4e9_row11_col7, #T_ff4e9_row12_col0, #T_ff4e9_row12_col1, #T_ff4e9_row12_col2, #T_ff4e9_row12_col3, #T_ff4e9_row12_col4, #T_ff4e9_row12_col5, #T_ff4e9_row12_col6, #T_ff4e9_row12_col7, #T_ff4e9_row13_col0, #T_ff4e9_row13_col1, #T_ff4e9_row13_col2, #T_ff4e9_row13_col3, #T_ff4e9_row13_col4, #T_ff4e9_row13_col5, #T_ff4e9_row13_col6, #T_ff4e9_row13_col7 {
#   text-align: left;
# }
# #T_ff4e9_row0_col1, #T_ff4e9_row0_col2, #T_ff4e9_row0_col3, #T_ff4e9_row0_col4, #T_ff4e9_row0_col5, #T_ff4e9_row0_col6, #T_ff4e9_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ff4e9_row0_col8, #T_ff4e9_row1_col8, #T_ff4e9_row2_col8, #T_ff4e9_row3_col8, #T_ff4e9_row4_col8, #T_ff4e9_row6_col8, #T_ff4e9_row7_col8, #T_ff4e9_row9_col8, #T_ff4e9_row10_col8, #T_ff4e9_row11_col8, #T_ff4e9_row12_col8, #T_ff4e9_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ff4e9_row5_col8, #T_ff4e9_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ff4e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff4e9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ff4e9_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ff4e9_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ff4e9_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ff4e9_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ff4e9_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ff4e9_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ff4e9_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ff4e9_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff4e9_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_ff4e9_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_ff4e9_row0_col1" class="data row0 col1" >0.5627</td>
#       <td id="T_ff4e9_row0_col2" class="data row0 col2" >0.5600</td>
#       <td id="T_ff4e9_row0_col3" class="data row0 col3" >0.5764</td>
#       <td id="T_ff4e9_row0_col4" class="data row0 col4" >0.5721</td>
#       <td id="T_ff4e9_row0_col5" class="data row0 col5" >0.5737</td>
#       <td id="T_ff4e9_row0_col6" class="data row0 col6" >0.1249</td>
#       <td id="T_ff4e9_row0_col7" class="data row0 col7" >0.1250</td>
#       <td id="T_ff4e9_row0_col8" class="data row0 col8" >0.0540</td>
#     </tr>
#     <tr>
#       <th id="T_ff4e9_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_ff4e9_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_ff4e9_row1_col1" class="data row1 col1" >0.5440</td>
#       <td id="T_ff4e9_row1_col2" class="data row1 col2" >0.5481</td>
#       <td id="T_ff4e9_row1_col3" class="data row1 col3" >0.5633</td>
#       <td id="T_ff4e9_row1_col4" class="data row1 col4" >0.5530</td>
#       <td id="T_ff4e9_row1_col5" class="data row1 col5" >0.5577</td>
#       <td id="T_ff4e9_row1_col6" class="data row1 col6" >0.0873</td>
#       <td id="T_ff4e9_row1_col7" class="data row1 col7" >0.0874</td>
#       <td id="T_ff4e9_row1_col8" class="data row1 col8" >0.0900</td>
#     </tr>
#     <tr>
#       <th id="T_ff4e9_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_ff4e9_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ff4e9_row2_col1" class="data row2 col1" >0.5380</td>
#       <td id="T_ff4e9_row2_col2" class="data row2 col2" >0.5456</td>
#       <td id="T_ff4e9_row2_col3" class="data row2 col3" >0.5463</td>
#       <td id="T_ff4e9_row2_col4" class="data row2 col4" >0.5493</td>
#       <td id="T_ff4e9_row2_col5" class="data row2 col5" >0.5474</td>
#       <td id="T_ff4e9_row2_col6" class="data row2 col6" >0.0757</td>
#       <td id="T_ff4e9_row2_col7" class="data row2 col7" >0.0758</td>
#       <td id="T_ff4e9_row2_col8" class="data row2 col8" >0.0760</td>
#     </tr>
#     <tr>
#       <th id="T_ff4e9_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_ff4e9_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ff4e9_row3_col1" class="data row3 col1" >0.5280</td>
#       <td id="T_ff4e9_row3_col2" class="data row3 col2" >0.5449</td>
#       <td id="T_ff4e9_row3_col3" class="data row3 col3" >0.5450</td>
#       <td id="T_ff4e9_row3_col4" class="data row3 col4" >0.5389</td>
#       <td id="T_ff4e9_row3_col5" class="data row3 col5" >0.5414</td>
#       <td id="T_ff4e9_row3_col6" class="data row3 col6" >0.0554</td>
#       <td id="T_ff4e9_row3_col7" class="data row3 col7" >0.0555</td>
#       <td id="T_ff4e9_row3_col8" class="data row3 col8" >0.0860</td>
#     </tr>
#     <tr>
#       <th id="T_ff4e9_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_ff4e9_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_ff4e9_row4_col1" class="data row4 col1" >0.5267</td>
#       <td id="T_ff4e9_row4_col2" class="data row4 col2" >0.5381</td>
#       <td id="T_ff4e9_row4_col3" class="data row4 col3" >0.5385</td>
#       <td id="T_ff4e9_row4_col4" class="data row4 col4" >0.5369</td>
#       <td id="T_ff4e9_row4_col5" class="data row4 col5" >0.5375</td>
#       <td id="T_ff4e9_row4_col6" class="data row4 col6" >0.0529</td>
#       <td id="T_ff4e9_row4_col7" class="data row4 col7" >0.0529</td>
#       <td id="T_ff4e9_row4_col8" class="data row4 col8" >0.0880</td>
#     </tr>
#     <tr>
#       <th id="T_ff4e9_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_ff4e9_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_ff4e9_row5_col1" class="data row5 col1" >0.5253</td>
#       <td id="T_ff4e9_row5_col2" class="data row5 col2" >0.5265</td>
#       <td id="T_ff4e9_row5_col3" class="data row5 col3" >0.5123</td>
#       <td id="T_ff4e9_row5_col4" class="data row5 col4" >0.5364</td>
#       <td id="T_ff4e9_row5_col5" class="data row5 col5" >0.5232</td>
#       <td id="T_ff4e9_row5_col6" class="data row5 col6" >0.0511</td>
#       <td id="T_ff4e9_row5_col7" class="data row5 col7" >0.05

# %%
model = create_model('lr', cross_validation=False, return_train_score=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b4d0a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4d0a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b4d0a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b4d0a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b4d0a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b4d0a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b4d0a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b4d0a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4d0a_level0_row0" class="row_heading level0 row0" >Test</th>
#       <td id="T_b4d0a_row0_col0" class="data row0 col0" >0.5433</td>
#       <td id="T_b4d0a_row0_col1" class="data row0 col1" >0.5444</td>
#       <td id="T_b4d0a_row0_col2" class="data row0 col2" >0.5463</td>
#       <td id="T_b4d0a_row0_col3" class="data row0 col3" >0.5542</td>
#       <td id="T_b4d0a_row0_col4" class="data row0 col4" >0.5502</td>
#       <td id="T_b4d0a_row0_col5" class="data row0 col5" >0.0865</td>
#       <td id="T_b4d0a_row0_col6" class="data row0 col6" >0.0865</td>
#     </tr>
#     <tr>
#       <th id="T_b4d0a_level0_row1" class="row_heading level0 row1" >Train</th>
#       <td id="T_b4d0a_row1_col0" class="data row1 col0" >0.5367</td>
#       <td id="T_b4d0a_row1_col1" class="data row1 col1" >0.5440</td>
#       <td id="T_b4d0a_row1_col2" class="data row1 col2" >0.5254</td>
#       <td id="T_b4d0a_row1_col3" class="data row1 col3" >0.5490</td>
#       <td id="T_b4d0a_row1_col4" class="data row1 col4" >0.5370</td>
#       <td id="T_b4d0a_row1_col5" class="data row1 col5" >0.0738</td>
#       <td id="T_b4d0a_row1_col6" class="data row1 col6" >0.0739</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned = tune_model(model, fold = 5, optimize = 'precision', return_train_score=True, n_iter=50)

# %%
ens_bagging = ensemble_model(model, fold = 5, method='Bagging', verbose=False)

# %%
def filtra_resultados(_df, filtro = 0):
    _df = _df[_df['prediction_label'] == 1]

    if filtro == 1:
        _df = _df[((_df['Odds'] > 1.85))]
        _df = _df[((_df['CV_ML'] < 0.7))]
    if filtro == 2:
        _df = _df[((_df['Odds'] > 1.85))]
        _df = _df[((_df['Over_Line'] >= 200) & (_df['Over_Line'] < 212)) | ((_df['Over_Line'] >= 215) & (_df['Over_Line'] < 218))]
    if filtro == 3:
        _df = _df[((_df['Odds'] > 1.85))]
        _df = _df[((_df['Over_Line'] >= 200) & (_df['Over_Line'] < 212)) | ((_df['Over_Line'] >= 214) & (_df['Over_Line'] < 217)) | ((_df['Over_Line'] >= 223) & (_df['Over_Line'] < 226)) | ((_df['Over_Line'] >= 232) & (_df['Over_Line'] < 400))]
        
    return _df

# %%
def calcula_profit(_df, stake = 1):
    _df.loc[(_df[TARGET] == 1), 'PL_BF_Predictions'] = (_df[ODDS] - 1) * stake
    _df.loc[(_df[TARGET] == 0), 'PL_BF_Predictions'] = - stake

    return _df

def exibe_metricas(_df, total, stake = 1, return_metrics = False):
    plb = _df['PL_BF_Predictions'].sum()
    entradas = _df.shape[0]
    wr = round((_df[_df[TARGET] == 1].shape[0] / entradas), 2)
    oddback = (_df[ODDS].mean())
    med_gain = _df[_df[TARGET] == 1]['PL_BF_Predictions'].mean()
    med_loss = _df[_df[TARGET] == 0]['PL_BF_Predictions'].mean()
    roi = plb / entradas
    porc_ent = entradas / total
    ev = (wr*stake*med_gain) + ((1-wr)*med_loss*stake)

    if return_metrics == False:
        print(f'PL: {plb:.2f} | ROI: {100*roi:.2f}% | Prec.: {wr:.2f}')
        print(f'Odd média: {oddback:.2f} ({1/oddback:.2f} WR)')
        print(f'Média Gain: {med_gain:.2f} | Média Loss: {med_loss:.2f}')
        print(f'EM: {ev:.2f}')
        print(f'{entradas} entradas em {total} jogos ({100*porc_ent:.2f}%)')
    else:
        return_metrics == True
        metrics = [plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev]
        return metrics

def exibe_grafico(_df):
    _df.sort_index(inplace=True)
    _df.reset_index(drop=True, inplace=True)
    _df['hbacu'] = _df['PL_BF_Predictions'].cumsum()
    _df['hbacu'].plot.line(figsize=(7,2))
    plt.show()

def treina_modelo(modelo, data):
    _df = predict_model(modelo, data, verbose = False)
    _df = _df.merge(df[[TARGET]], left_index=True, right_index=True, how='left')
    if f'{TARGET}_x' in _df.columns.tolist():
        _df.rename(columns={f'{TARGET}_x': TARGET}, inplace=True)
        _df.drop(columns=f'{TARGET}_y', inplace=True)
    
    return _df

def info_modelo(modelo, data, stake = 1, filtro = 0):
    total = data.shape[0]

    _df = treina_modelo(modelo, data)
    _df = filtra_resultados(_df, filtro=filtro)
    _df = calcula_profit(_df, stake)
    exibe_metricas(_df, total, stake)
    exibe_grafico(_df)
    
    return _df

# %%
mdl = model
flt = 2
df_tr = info_modelo(mdl, real_treino, filtro = flt)
df_teste = info_modelo(mdl, real_teste, filtro = flt)
df_comp = info_modelo(mdl, treino, filtro = flt)
# Out:
# PL: 40.07 | ROI: 19.64% | Prec.: 0.63
# Odd média: 1.89 (0.53 WR)
# Média Gain: 0.89 | Média Loss: -1.00
# EM: 0.19
# 204 entradas em 1500 jogos (13.60%)
# PL: 34.98 | ROI: 21.07% | Prec.: 0.64
# Odd média: 1.89 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.21
# 166 entradas em 1500 jogos (11.07%)
# PL: 75.05 | ROI: 20.28% | Prec.: 0.64
# Odd média: 1.89 (0.53 WR)
# Média Gain: 0.89 | Média Loss: -1.00
# EM: 0.21
# 370 entradas em 3000 jogos (12.33%)

# %%
df_val = info_modelo(mdl, val1, filtro = flt)
# Out:
# PL: 17.52 | ROI: 12.34% | Prec.: 0.59
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.12
# 142 entradas em 2146 jogos (6.62%)

# %%
plt.axvline(x=len(df_comp), color='red', linestyle='--')
df_completo = info_modelo(mdl, pd.concat([treino, val1, val2]), filtro = flt)
# Out:
# PL: 90.57 | ROI: 17.62% | Prec.: 0.62
# Odd média: 1.89 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.18
# 514 entradas em 5305 jogos (9.69%)

# %% [markdown]
# # Comparação de modelos

# %% [markdown]
# ### Escolhendo os modelos

# %%
FILTRO = 2
CONJUNTO = 'val'

for i in range(14):
    try:
        if CONJUNTO != 'teste':
            print(f'{top[i].__class__.__name__} (i = {i})\n')
            aux_tr = treina_modelo(top[i], real_teste)
            aux_tr = filtra_resultados(aux_tr, filtro = FILTRO)
            plt.axvline(x=len(aux_tr), color='red', linestyle='--')
            aux_total = treina_modelo(top[i], val1)
            aux_total = filtra_resultados(aux_total, filtro = FILTRO)
            plt.axvline(x=len(aux_total) + len(aux_tr), color='blue', linestyle='--')
            aux = info_modelo(top[i], pd.concat([real_teste, val1, val2]), filtro = FILTRO)
        else:
            print(f'{top[i].__class__.__name__} (i = {i})\n')
            aux = info_modelo(top[i], real_teste, filtro = FILTRO)
    except:
        print(f'O modelo apresentou um erro.\n')
        pass
# Out:
# DecisionTreeClassifier (i = 0)
#
# PL: 4.65 | ROI: 1.17% | Prec.: 0.53
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.01
# 398 entradas em 3805 jogos (10.46%)
# RandomForestClassifier (i = 1)
#
# PL: -2.82 | ROI: -0.72% | Prec.: 0.52
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: -0.01
# 394 entradas em 3805 jogos (10.35%)
# XGBClassifier (i = 2)
#
# PL: 10.53 | ROI: 2.55% | Prec.: 0.54
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.03
# 413 entradas em 3805 jogos (10.85%)
# LGBMClassifier (i = 3)
#
# PL: 20.69 | ROI: 4.71% | Prec.: 0.55
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.04
# 439 entradas em 3805 jogos (11.54%)
# ExtraTreesClassifier (i = 4)
#
# PL: -0.89 | ROI: -0.23% | Prec.: 0.53
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.01
# 379 entradas em 3805 jogos (9.96%)
# LinearDiscriminantAnalysis (i = 5)
#
# PL: 49.80 | ROI: 16.33% | Prec.: 0.61
# Odd média: 1.89 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.16
# 305 entradas em 3805 jogos (8.02%)
# LogisticRegression (i = 6)
#
# PL: 50.50 | ROI: 16.29% | Prec.: 0.61
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.16
# 310 entradas em 3805 jogos (8.15%)
# KNeighborsClassifier (i = 7)
#
# PL: 3.77 | ROI: 0.92% | Prec.: 0.53
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.01
# 409 entradas em 3805 jogos (10.75%)
# RidgeClassifier (i = 8)
#
# PL: 49.70 | ROI: 16.19% | Prec.: 0.61
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.16
# 307 entradas em 3805 jogos (8.07%)
# SGDClassifier (i = 9)
#
# PL: 10.43 | ROI: 2.48% | Prec.: 0.54
# Odd média: 1.91 (0.52 WR)
# Média Gain: 0.91 | Média Loss: -1.00
# EM: 0.03
# 421 entradas em 3805 jogos (11.06%)
# GaussianNB (i = 10)
#
# PL: 32.35 | ROI: 7.51% | Prec.: 0.57
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.08
# 431 entradas em 3805 jogos (11.33%)
# AdaBoostClassifier (i = 11)
#
# PL: 33.90 | ROI: 8.15% | Prec.: 0.57
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.08
# 416 entradas em 3805 jogos (10.93%)
# GradientBoostingClassifier (i = 12)
#
# PL: 22.12 | ROI: 6.28% | Prec.: 0.56
# Odd média: 1.90 (0.53 WR)
# Média Gain: 0.90 | Média Loss: -1.00
# EM: 0.06
# 352 entradas em 3805 jogos (9.25%)
# QuadraticDiscriminantAnalysis (i = 13)
#
# O modelo apresentou um erro.

# %%
blended18 = blend_models(estimator_list = [top[1], top[8]], fold = 5, verbose=False)

# %%
model_list = [top[1], top[8], blended18]

# %% [markdown]
# ### Resultados

# %%
FILTRO = 2

for item in model_list:
    try:
        print(f'{item.__class__.__name__}\n')
        aux_tr = treina_modelo(item, real_teste)
        aux_tr = filtra_resultados(aux_tr, filtro = FILTRO)
        plt.axvline(x=len(aux_tr), color='red', linestyle='--')
        aux_total = treina_modelo(item, val1)
        aux_total = filtra_resultados(aux_total, filtro = FILTRO)
        plt.axvline(x=len(aux_total) + len(aux_tr), color='blue', linestyle='--')
        aux = info_modelo(item, pd.concat([real_teste, val]), filtro = FILTRO)
    except:
        print(f'O modelo apresentou um erro.\n')
        pass
# Out:
# GaussianNB
#
# PL: 26.46 | ROI: 11.92% | Prec.: 0.54
# Odd média: 2.11 (0.47 WR)
# Média Gain: 1.07 | Média Loss: -1.00
# EM: 0.12
# 222 entradas em 1637 jogos (13.56%)
# KNeighborsClassifier
#
# PL: 19.83 | ROI: 11.53% | Prec.: 0.53
# Odd média: 2.14 (0.47 WR)
# Média Gain: 1.11 | Média Loss: -1.00
# EM: 0.12
# 172 entradas em 1637 jogos (10.51%)
# VotingClassifier
#
# PL: 19.81 | ROI: 9.43% | Prec.: 0.53
# Odd média: 2.10 (0.48 WR)
# Média Gain: 1.05 | Média Loss: -1.00
# EM: 0.09
# 210 entradas em 1637 jogos (12.83%)

# %% [markdown]
# # Script qcut

# %%
# df_cut1 = df_treino.copy()
df_cut = df_comp.copy()
# df_cut = pd.concat([df_cut1, df_cut2])

# %%
variaveis = features.copy()
variaveis.append('prediction_score')

for var in variaveis:
    try:
        nome = f'Cat_{var}'
        # Usa qcut para definir os grupos
        df_cut[nome]  = pd.qcut(df_cut[var], q = 10, duplicates='drop')

        target = 'PL_BF_Predictions'
        pivot_table = pd.pivot_table(df_cut,
                                    values=target,
                                    index=[nome],
                                    aggfunc=['sum', 'count']
                                    )
        

        pivot_table['ratio'] = pivot_table[('sum', target)] / pivot_table[('count', target)]

        aux_treino = pivot_table[pivot_table['ratio'] != 0]


        print(var)
        print(aux_treino)
        print()
        print('\n\n')
        print('------------------------------------------------')
        print('\n\n')
    except:
        pass
# Out:
# Odds_H
#                                          sum             count     ratio
#                            PL_BF_Predictions PL_BF_Predictions
# Cat_Odds_H
# (1.0190000000000001, 1.11]          5.279999               149  0.035436
# (1.11, 1.2]                         1.659998               179  0.009274
# (1.2, 1.27]                       -11.920001               135 -0.088296
# (1.27, 1.33]                       31.039999               132  0.235152
# (1.33, 1.4]                        11.079999               137  0.080876
# (1.4, 1.47]                        -3.720001               142 -0.026197
# (1.47, 1.68]                       34.430000               168  0.204940
# (1.68, 1.8]                        -8.310000               133 -0.062481
# (1.8, 2.035]                       -4.390001               133 -0.033008
# (2.035, 5.25]                      11.169999               146  0.076507
#
#
#
#
# ------------------------------------------------
#
#
#
# Odds_Over
#                                         sum             count     ratio
#                           PL_BF_Predictions PL_BF_Predictions
# Cat_Odds_Over
# (1.7990000000000002, 1.9]         69.519989              1447  0.048044
# (1.9, 1.95]                       -3.200000                 7 -0.457143
#
#
#
#
# ------------------------------------------------
#
#
#
# Odds_Under
#                                         sum             count     ratio
#                           PL_BF_Predictions PL_BF_Predictions
# Cat_Odds_Under
# (1.8290000000000002, 1.9]         59.209988              1425  0.041551
# (1.9, 2.05]                        7.110000                29  0.245172
#
#
#
#
# ------------------------------------------------
#
#
#
# Over_Line
#                                sum             count     ratio
#                  PL_BF_Predictions PL_BF_Predictions
# Cat_Over_Line
# (200.499, 211.5]         38.969997               169  0.230592
# (211.5, 214.5]          -14.360001               136 -0.105588
# (214.5, 216.5]           26.699999               144  0.185417
# (216.5, 219.5]           -1.130002               189 -0.005979
# (219.5, 221.5]           -6.240001               152 -0.041053
# (221.5, 223.5]           -1.710001               127 -0.013465
# (223.5, 225.5]           17.849998               115  0.155217
# (225.5, 228.5]            3.149999               158  0.019937
# (228.5, 232.5]          -10.950001               136 -0.080515
# (232.5, 310.5]           14.039999               128  0.109687
#
#
#
#
# ------------------------------------------------
#
#
#
# HA_Line
#                                sum             count     ratio
#                  PL_BF_Predictions PL_BF_Predictions
# Cat_HA_Line
# (-18.501, -12.5]          1.639999               162  0.010123
# (-12.5, -10.5]            3.169999               168  0.018869
# (-10.5, -8.5]            26.949999               208  0.129567
# (-8.5, -7.5]             29.149998               151  0.193046
# (-7.5, -6.5]             -4.140001               139 -0.029784
# (-6.5, -5.5]              8.049999               130  0.061923
# (-5.5, -4.5]             11.089999                74  0.149865
# (-4.5, -2.5]              4.369998               211  0.020711
# (-2.5, -1.5]             -4.770001               139 -0.034317
# (-1.5, 6.5]              -9.190001                72 -0.127639
#
#
#
#
# ------------------------------------------------
#
#
#
# P(A)
#                               sum             count     ratio
#                 PL_BF_Predictions PL_BF_Predictions
# Cat_P(A)
# (0.0578, 0.148]          5.279999               149  0.035436
# (0.148, 0.211]           1.859998               175  0.010629
# (0.211, 0.256]         -12.570001               113 -0.111239
# (0.256, 0.294]          29.730000               156  0.190577
# (0.294, 0.328]          12.839998               139  0.092374
# (0.328, 0.364]          -4.580001               141 -0.032482
# (0.364, 0.444]          34.689999               162  0.214136
# (0.444, 0.488]          -9.510001               138 -0.068913
# (0.488, 0.553]          -2.590001               135 -0.019185
# (0.553, 0.847]          11.169999               146  0.076507
#
#
#
#
# ------------------------------------------------
#
#
#
# P(O)
#                              sum             count     ratio
#                PL_BF_Predictions PL_BF_Predictions
# Cat_P(O)
# (0.512, 0.526]         57.529987              1404  0.040976
# (0.526, 0.556]          8.789999                50  0.175800
#
#
#
#
# ------------------------------------------------
#
#
#
# P(U)
#                              sum             count     ratio
#                PL_BF_Predictions PL_BF_Predictions
# Cat_P(U)
# (0.487, 0.526]          61.57999              1419  0.043397
# (0.526, 0.546]           4.74000                35  0.135429
#
#
#
#
# ------------------------------------------------
#
#
#
# P_Diff
#                                sum             count     ratio
#                  PL_BF_Predictions PL_BF_Predictions
# Cat_P_Diff
# (0.0257, 0.037]          27.070000               147  0.184150
# (0.037, 0.0398]          14.329999               171  0.083801
# (0.0398, 0.0424]         10.419999               132  0.078939
# (0.0424, 0.0433]          0.739999               138  0.005362
# (0.0433, 0.0438]          8.479999               149  0.056913
# (0.0438, 0.0439]         -5.800001               139 -0.041727
# (0.0439, 0.0453]          4.089999               153  0.026732
# (0.0453, 0.0467]        -14.520001               134 -0.108358
# (0.0467, 0.0505]          7.859999               187  0.042032
# (0.0505, 0.0753]         13.650000               104  0.131250
#
#
#
#
# ------------------------------------------------
#
#
#
# CV_ML
#                                sum             count     ratio
#                  PL_BF_Predictions PL_BF_Predictions
# Cat_CV_ML
# (-0.001, 0.0918]          2.169999               187  0.011604
# (0.0918, 0.174]          10.200000               105  0.097143
# (0.174, 0.296]           20.330000               144  0.141181
# (0.296, 0.449]           -1.080001               162 -0.006667
# (0.449, 0.553]           17.299999               144  0.120139
# (0.553, 0.626]            2.879999               130  0.022154
# (0.626, 0.721]           18.949999               146  0.129795
# (0.721, 0.844]          -21.100000               150 -0.140667
# (0.844, 1.015]           16.399998               153  0.107190
# (1.015, 1.254]            0.269999               133  0.002030
#
#
#
#
# ------------------------------------------------
#
#
#
# CV_Over
#                                sum             count     ratio
#                  PL_BF_Predictions PL_BF_Predictions
# Cat_CV_Over
# (-0.001, 0.0918]         66.319992              1454  0.045612
#
#
#
#
# ------------------------------------------------
#
#
#
# Odds
#                                         sum             count     ratio
#                           PL_BF_Predictions PL_BF_Predictions
# Cat_Odds
# (1.8590000000000002, 1.9]         64.919991              1385  0.046874
# (1.9, 2.05]                        1.400002                69  0.020290
#
#
#
#
# ------------------------------------------------
#
#
#
# prediction_score
#                                    sum             count     ratio
#                      PL_BF_Predictions PL_BF_Predictions
# Cat_prediction_score
# (0.499, 0.505]               -1.540001               150 -0.010267
# (0.505, 0.51]                 9.979999               144  0.069306
# (0.51, 0.516]                 1.019999               145  0.007034
# (0.516, 0.522]                3.839999               144  0.026667
# (0.522, 0.528]               -5.550001               144 -0.038542
# (0.528, 0.535]               12.189999               149  0.081812
# (0.535, 0.542]               11.479999               142  0.080845
# (0.542, 0.553]                1.639999               146  0.011233
# (0.553, 0.57]                -3.960001               144 -0.027500
# (0.57, 0.764]                37.219997               146  0.254931
#
#
#
#
# ------------------------------------------------

# %%
_df = _df[((_df['Over_Line'] >= 200) & (_df['Over_Line'] < 212)) | ((_df['Over_Line'] >= 214) & (_df['Over_Line'] < 217))]
_df = _df[((_df['Over_Line'] >= 223) & (_df['Over_Line'] < 226)) | ((_df['Over_Line'] >= 232) & (_df['Over_Line'] < 400))]

_df = _df[((_df['P_Diff'] < 0.0438) | (_df['P_Diff'] > 0.25))]

# %%
# display(df_cut2.groupby('Cat_DP_Odds_Geral_H')['DP_Odds_Geral_H'].describe())

# %% [markdown]
# # Script variáveis

# %%
colunas = ['Odds_H', 'Odds_A', 'Over_Line', 'Odds_Over', 'Odds_Under', 'HA_Line',
       'HA_Odds_H', 'HA_Odds_A', 'P(H)', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'Porc_Over_Home',
       'Porc_Over_Away', 'Avg_CG_H', 'DP_CG_H',
       'CV_CG_H', 'Avg_CG_A', 'DP_CG_A', 'CV_CG_A', 'MediaCustoGolHome',
       'MediaCustoGolAway', 'Last_CG_H', 'Last_CG_A', 'Acima_Last_CG_H',
       'Acima_Last_CG_A', 'Abaixo_Last_CG_H', 'Abaixo_Last_CG_A', 'CV_ML',
       'CV_Over', 'CV_HA', 'Retornos_BH_Acu', 'Avg_Retornos_BH', 'Custo_Retorno_BH',
       'Avg_Porc_BH_Bookie', 'Avg_Porc_BH_Real', 'Dist_Porc_BH',
       'Retornos_BA_Acu', 'Avg_Retornos_BA', 'Custo_Retorno_BA',
       'Avg_Porc_BA_Bookie', 'Avg_Porc_BA_Real', 'Dist_Porc_BA']

colunas = ['Odds_H', 'Odds_A', 'Odds_Over', 'Odds_Under', 'Over_Line',  'HA_Line', 'HA_Odds_H', 'HA_Odds_A', 'P(H)', 'P(A)', 
       'P(O)', 'P(U)', 'P_Diff', 'CV_ML',
       'CV_Over', 'CV_HA']

# %%
import random

def pegar_elementos_aleatorios(lista):
    # Gerar um número aleatório entre 2 e 7
    num_elementos = random.randint(5, 12)

    # Garantir que o número de elementos não ultrapasse o tamanho da lista
    num_elementos = min(num_elementos, len(lista))

    # Selecionar elementos aleatórios da lista
    elementos_aleatorios = random.sample(lista, num_elementos)

    return elementos_aleatorios

# %%
def cria_modelo(fts, _seed = 2023, _filtro = 0):
        try:
                cria_setup(features=fts, seed = _seed)

                model = create_model('lr', verbose = False, fold = 5)
                tab = pull()
                prec_model = (tab.loc['Mean', 'Prec.'])
                previsoes = predict_model(model, verbose = False)

                stake = 1

                total = previsoes.shape[0]

                previsoes = previsoes[previsoes['prediction_label'] == 1]
                previsoes = filtra_resultados(previsoes, filtro = _filtro)

                previsoes.loc[(previsoes[TARGET] == 1), 'PL_BF_Predictions'] = (previsoes[ODDS] - 1) * stake
                previsoes.loc[(previsoes[TARGET] == 0), 'PL_BF_Predictions'] = - stake

                plb = previsoes['PL_BF_Predictions'].sum()
                entradas = previsoes.shape[0]
                wr = round((previsoes[previsoes[TARGET] == 1].shape[0] / entradas), 2)
                oddback = previsoes[previsoes['prediction_label'] == 1][ODDS].mean()
                med_gain = previsoes[previsoes[TARGET] == 1]['PL_BF_Predictions'].mean()
                med_loss = previsoes[previsoes[TARGET] == 0]['PL_BF_Predictions'].mean()
                roi = plb / entradas
                porc_ent = entradas / total
                ev = (wr*stake*med_gain) + ((1-wr)*med_loss*stake)

                metrics = [prec_model, plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev]

                return metrics
        except Exception as e:
                print(e)
                return [0, 0, 0, 0, 0, 0, 0, 0, 0]

# %%
melhor_PL = -10000

for i in range(20):
    feats = pegar_elementos_aleatorios(colunas)
    feats.append(ODDS)

    metrics = cria_modelo(fts=feats)
    prec_model, plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev = metrics
            
    print(f'Rodada {i+1}')
    if plb > melhor_PL:
        melhor_PL = plb
        print(f'**Novo melhor**')
        print(f'Precision: {prec_model:.4f}')
        print(f'PL: {plb:.2f} | ROI: {100*roi:.2f}% | EM: {ev:.2f} | Prec.: {wr:.2f} | Entradas: {porc_ent:.2f}')
        print(f'features = {feats}\n')
    print()
# Out:
# Rodada 1
# **Novo melhor**
# Precision: 0.4040
# PL: -57.26 | ROI: -15.73% | EM: -0.16 | Prec.: 0.38 | Entradas: 0.49
# features = ['Over_Line', 'CV_ML', 'Odds_Under', 'HA_Odds_A', 'P(U)', 'P_Diff', 'CV_Over', 'P(H)', 'Odds']
#
#
# Rodada 2
# **Novo melhor**
# Precision: 0.4094
# PL: -50.24 | ROI: -14.78% | EM: -0.16 | Prec.: 0.39 | Entradas: 0.46
# features = ['HA_Line', 'Odds_H', 'P(H)', 'P_Diff', 'Odds_Over', 'CV_HA', 'P(U)', 'CV_Over', 'P(A)', 'CV_ML', 'Odds']
#
#
# Rodada 3
#
# Rodada 4
# **Novo melhor**
# Precision: 0.4263
# PL: -48.52 | ROI: -13.86% | EM: -0.14 | Prec.: 0.39 | Entradas: 0.47
# features = ['HA_Line', 'P(O)', 'CV_Over', 'P(H)', 'Over_Line', 'Odds']
#
#
# Rodada 5
#
# Rodada 6
# **Novo melhor**
# Precision: 0.4068
# PL: -47.08 | ROI: -12.93% | EM: -0.14 | Prec.: 0.39 | Entradas: 0.49
# features = ['Odds_Over', 'HA_Odds_H', 'Odds_A', 'P(H)', 'HA_Odds_A', 'Odds_Under', 'CV_Over', 'CV_ML', 'Over_Line', 'P_Diff', 'P(A)', 'P(O)', 'Odds']
#
#
# Rodada 7
#
# Rodada 8
#
# Rodada 9
# **Novo melhor**
# Precision: 0.3952
# PL: -46.74 | ROI: -12.46% | EM: -0.12 | Prec.: 0.40 | Entradas: 0.50
# features = ['Odds_H', 'HA_Odds_A', 'Odds_Over', 'P_Diff', 'P(A)', 'CV_ML', 'Odds_A', 'P(H)', 'CV_Over', 'Odds']
#
#
# Rodada 10
#
# Rodada 11
#
# Rodada 12
#
# Rodada 13
#
# Rodada 14
# **Novo melhor**
# Precision: 0.4017
# PL: -41.09 | ROI: -11.11% | EM: -0.12 | Prec.: 0.40 | Entradas: 0.50
# features = ['HA_Line', 'P(O)', 'CV_Over', 'CV_ML', 'HA_Odds_H', 'P(U)', 'Odds_A', 'Odds_H', 'P_Diff', 'Odds']
#
#
# Rodada 15
#
# Rodada 16
#
# Rodada 17
#
# Rodada 18
#
# Rodada 19
#
# Rodada 20

# %% [markdown]
# # Segundo filtro

# %%
fits = ['Odds_H', 'Odds_A', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line',  'P(H)', 'P(A)', 
       'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'CV_HA', ODDS]

fits = ['Odds_H', 'Odds_A', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(H)', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']

fits = ['Odds_H', 'Odds_A', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']

fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']

# %%
metrics = cria_modelo(fits)
prec_model, plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev = metrics

print('---------------------- BASE ----------------------')
print(f'Precision: {prec_model:.4f}')
print(f'PL: {plb:.2f} | ROI: {100*roi:.2f}% | EM: {ev:.2f} | Prec.: {wr:.2f} | Entradas: {porc_ent:.2f}')
print(f'fits = {fits}\n')
print('--------------------------------------------------')
melhor_PL = plb

for i in range(len(fits) - 1):
    feat = fits[i]
    fits.pop(i)
    print(f'Removido: {feat}')

    metrics = cria_modelo(fits)
    prec_model, plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev = metrics

    if plb >= melhor_PL:
        print('*** NOVO MELHOR ***')
        melhor_PL = plb
    print(f'Precision: {prec_model:.4f}')
    print(f'PL: {plb:.2f} | ROI: {100*roi:.2f}% | EM: {ev:.2f} | Prec.: {wr:.2f} | Entradas: {porc_ent:.2f}')
    print(f'fits = {fits}\n')
    fits.insert(i, feat)
    print()
# Out:
# ---------------------- BASE ----------------------
# Precision: 0.5410
# PL: 33.76 | ROI: 3.96% | EM: 0.04 | Prec.: 0.55 | Entradas: 0.57
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
# --------------------------------------------------
# Removido: Odds_H
# Precision: 0.5359
# PL: 16.31 | ROI: 1.87% | EM: 0.02 | Prec.: 0.54 | Entradas: 0.58
# fits = ['Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: Odds_Over
# Precision: 0.5337
# PL: 31.23 | ROI: 3.58% | EM: 0.04 | Prec.: 0.55 | Entradas: 0.58
# fits = ['Odds_H', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: Odds_Under
# Precision: 0.5357
# PL: 30.56 | ROI: 3.70% | EM: 0.04 | Prec.: 0.55 | Entradas: 0.55
# fits = ['Odds_H', 'Odds_Over', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: Over_Line
# Precision: 0.5301
# PL: 31.81 | ROI: 3.65% | EM: 0.04 | Prec.: 0.55 | Entradas: 0.58
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: HA_Line
# Precision: 0.5254
# PL: 8.88 | ROI: 1.02% | EM: 0.00 | Prec.: 0.53 | Entradas: 0.58
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: P(A)
# Precision: 0.5348
# PL: 28.25 | ROI: 3.26% | EM: 0.04 | Prec.: 0.55 | Entradas: 0.58
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: P(O)
# Precision: 0.5351
# PL: 31.98 | ROI: 3.84% | EM: 0.04 | Prec.: 0.55 | Entradas: 0.55
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: P(U)
# Precision: 0.5347
# PL: 26.23 | ROI: 3.07% | EM: 0.02 | Prec.: 0.54 | Entradas: 0.57
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P_Diff', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: P_Diff
# Precision: 0.5310
# PL: 16.02 | ROI: 1.87% | EM: 0.02 | Prec.: 0.54 | Entradas: 0.57
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'CV_ML', 'CV_Over', 'Odds']
#
#
# Removido: CV_ML
# *** NOVO MELHOR ***
# Precision: 0.5395
# PL: 34.00 | ROI: 4.29% | EM: 0.04 | Prec.: 0.55 | Entradas: 0.53
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_Over', 'Odds']
#
#
# Removido: CV_Over
# Precision: 0.5439
# PL: 15.86 | ROI: 1.84% | EM: 0.02 | Prec.: 0.54 | Entradas: 0.58
# fits = ['Odds_H', 'Odds_Over', 'Odds_Under', 'Over_Line', 'HA_Line', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'Odds']

# %% [markdown]
# # Cross validation

# %%
ftrs = ['Avg_Porc_BA_Real', 'P(A)', 'P(O)', 'MediaCustoGolAway', 'HA_Odds_H', 'CV_Over', 'Retornos_BH_Acu', 'P(U)', 'Avg_Porc_BA_Bookie', 'DP_CG_H', 'Retornos_BA_Acu', 'Last_CG_H', 'Porc_Over_Away', 'Avg_Porc_BH_Real', 'CV_CG_H', 'Odds']

# %%
results = []
seeds = random.sample(range(0, 9999), 10)

for i in range(len(seeds)):

        cria_setup(seed=seeds[i], features=ftrs)

        cross_model = create_model('lr', verbose = False, cross_validation=False)
        
        previsoes = predict_model(cross_model, real_teste, verbose = False)
        previsoes = previsoes.merge(df[ODDS], left_index=True, right_index=True, how='left')
        if f'{ODDS}_x' in previsoes.columns.tolist():
                previsoes.rename(columns={f'{ODDS}_x': ODDS}, inplace=True)
                previsoes.drop(columns=f'{ODDS}_y', inplace=True)

        stake = 1

        total = previsoes.shape[0]

        previsoes = previsoes[(previsoes['prediction_label'] == 1)]

        previsoes.loc[(previsoes[TARGET] == 1), 'PL_BF_Predictions'] = (previsoes[ODDS] - 1) * stake
        previsoes.loc[(previsoes[TARGET] == 0), 'PL_BF_Predictions'] = - stake

        ############ Filtro ############
        previsoes = filtra_resultados(previsoes, filtro = 0)
        previsoes = calcula_profit(previsoes)
        metrics = exibe_metricas(previsoes, total = total, return_metrics=True)
        plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev = metrics
        
        results.append(wr)

        print(f'Fold {i+1} (seed {seeds[i]})')
        print(f'PL: {plb:.2f} | ROI: {100*roi:.2f}% | EM: {ev:.2f} | Prec.: {wr:.2f} | Entradas: {porc_ent:.2f}')
        print()

print(f'Média: {np.mean(results):.2f} | DP: {np.std(results):.2f}')
# Out:
# Fold 1 (seed 9839)
# PL: -1.70 | ROI: -0.67% | EM: -0.01 | Prec.: 0.64 | Entradas: 0.51
#
# Fold 2 (seed 457)
# PL: -10.97 | ROI: -4.27% | EM: -0.04 | Prec.: 0.62 | Entradas: 0.51
#
# Fold 3 (seed 5673)
# PL: -7.25 | ROI: -2.70% | EM: -0.03 | Prec.: 0.63 | Entradas: 0.54
#
# Fold 4 (seed 2960)
# PL: -6.15 | ROI: -2.44% | EM: -0.03 | Prec.: 0.63 | Entradas: 0.50
#
# Fold 5 (seed 4170)
# PL: -0.36 | ROI: -0.14% | EM: -0.00 | Prec.: 0.64 | Entradas: 0.52
#
# Fold 6 (seed 2715)
# PL: -2.58 | ROI: -0.98% | EM: -0.02 | Prec.: 0.63 | Entradas: 0.53
#
# Fold 7 (seed 4190)
# PL: -2.06 | ROI: -0.89% | EM: -0.01 | Prec.: 0.64 | Entradas: 0.46
#
# Fold 8 (seed 1100)
# PL: -2.54 | ROI: -1.06% | EM: -0.01 | Prec.: 0.64 | Entradas: 0.48
#
# Fold 9 (seed 4678)
# PL: -6.83 | ROI: -2.71% | EM: -0.03 | Prec.: 0.63 | Entradas: 0.50
#
# Fold 10 (seed 2480)
# PL: -10.90 | ROI: -4.31% | EM: -0.04 | Prec.: 0.62 | Entradas: 0.51
#
# Média: 0.63 | DP: 0.01

# %% [markdown]
# # Entradas Aleatórias

# %%
def new_random_model(_val, _n):

    for i in range(_n):
        random_df = _val.copy()
        random_df['Entrada'] = [random.choice([0, 1]) for _ in range(len(random_df))]

        random_df = random_df[random_df['Entrada'] == 1]
        random_df.loc[(random_df[TARGET] == 1), 'PL'] = (random_df[ODDS] - 1)
        random_df.loc[(random_df[TARGET] == 0), 'PL'] = - 1
        
        random_df.sort_values('Date', inplace=True)
        random_df.reset_index(drop=True, inplace=True)
        random_df['hbacu'] = random_df['PL'].cumsum()
        random_df['hbacu'].plot.line(figsize=(12,6))
    
    plt.show()

# %%
new_random_model(val, 100)
