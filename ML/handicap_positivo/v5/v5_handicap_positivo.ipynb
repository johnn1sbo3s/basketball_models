# %%
import pandas as pd; pd.set_option('display.max_columns', None)
import numpy as np
import random
import matplotlib.pyplot as plt
from pycaret.classification import *

import sys
sys.path.append('../../../scripts/')
from PreparaDataset import *

# %% [markdown]
# # Parâmetros do método

# %%
TARGET = 'Back_HA_Zebra'
ODDS = 'Odds'

# %% [markdown]
# # Carregando o dataset

# %%
data = pd.read_csv('../../../data/Entire_Season.csv')

# %%
def prepara_dataset(_df):
    # HA
    _df.loc[(_df['Back_HA_H']) == 0, 'Back_HA_A'] = 1
    _df.loc[(_df['Back_HA_H']) == 1, 'Back_HA_A'] = 0
    _df.loc[(_df['Back_HA_H']) == 2, 'Back_HA_A'] = 2

    _df.loc[(_df['HA_Line']) > 0, 'Zebra'] = 'Casa'
    _df.loc[(_df['HA_Line']) < 0, 'Zebra'] = 'Fora'
    _df['Zebra'] = _df['Zebra'].astype('category')

    # Odds
    _df.loc[(_df['Zebra']) == 'Casa', 'Odds'] = _df['HA_Odds_H']
    _df.loc[(_df['Zebra']) == 'Fora', 'Odds'] = _df['HA_Odds_A']

    _df.loc[((_df['Zebra'] == 'Casa') & (_df['Back_HA_H'] == 1)), 'Back_HA_Zebra'] = 1
    _df.loc[((_df['Zebra'] == 'Casa') & (_df['Back_HA_H'] == 0)), 'Back_HA_Zebra'] = 0
    _df.loc[((_df['Zebra'] == 'Fora') & (_df['Back_HA_A'] == 1)), 'Back_HA_Zebra'] = 1
    _df.loc[((_df['Zebra'] == 'Fora') & (_df['Back_HA_A'] == 0)), 'Back_HA_Zebra'] = 0

    # Limpa _df
    _df.replace([np.inf, -np.inf], 0, inplace=True)
    _df.dropna(subset=[TARGET], inplace=True)
    # _df = _df[(_df['Avg_CG_H'] != 0) & (_df['Avg_CG_A'] != 0) & (_df['DP_CG_H'] != 0) & (_df['DP_CG_A'] != 0) & (_df['MediaCustoGolAway'] != 0)]

    _df = _df[_df['Date'] > '2023-10-21'] 

    _df.reset_index(drop=True, inplace=True)
    
    return _df

# %%
df = prepara_df(data)
df = prepara_dataset(df)

# %%
TRAIN_SIZE = 0.5
div = int(TRAIN_SIZE * len(df))

treino = df.iloc[:div, :]
val = df.iloc[div: , :]

print(f'Treino: {treino.shape[0]} | Validação: {val.shape[0]}')
print(f"Odd média: {treino[ODDS].mean():.2f}")
print(f"WR: {treino[TARGET].mean():.2f} (Odd justa: {1 / treino[TARGET].mean():.2f})")
# Out:
# Treino: 350 | Validação: 350
# Odd média: 1.88
# WR: 0.55 (Odd justa: 1.81)

# %% [markdown]
# # Validação 2

# %%
val1 = val[val['Date'] < '2023-10-20']
val2 = val[val['Date'] > '2023-10-19']

print(f'Validação 1: {val1.shape[0]} | Validação 2: {val2.shape[0]}')
# Out:
# Validação 1: 0 | Validação 2: 350

# %% [markdown]
# # Criação do modelo

# %%
features = ['Odds_H', 'Odds_A', 'Over_Line', 'Odds_Over', 'Odds_Under', 'HA_Line',
       'HA_Odds_H', 'HA_Odds_A', 'P(H)', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'Porc_Over_Home',
       'Porc_Over_Away', 'Avg_CG_H', 'DP_CG_H',
       'CV_CG_H', 'Avg_CG_A', 'DP_CG_A', 'CV_CG_A', 'MediaCustoGolHome',
       'MediaCustoGolAway', 'Last_CG_H', 'Last_CG_A', 'Acima_Last_CG_H',
       'Acima_Last_CG_A', 'Abaixo_Last_CG_H', 'Abaixo_Last_CG_A', 'CV_ML',
       'CV_Over', 'CV_HA', 'Retornos_BH_Acu', 'Avg_Retornos_BH', 'Custo_Retorno_BH',
       'Avg_Porc_BH_Bookie', 'Avg_Porc_BH_Real', 'Dist_Porc_BH',
       'Retornos_BA_Acu', 'Avg_Retornos_BA', 'Custo_Retorno_BA',
       'Avg_Porc_BA_Bookie', 'Avg_Porc_BA_Real', 'Dist_Porc_BA', ODDS]

features = ['Odds_H', 'Odds_A', 'Odds_Over', 'Odds_Under', 'Over_Line',  'HA_Line', 'HA_Odds_H', 'HA_Odds_A', 'P(H)', 'P(A)', 
       'P(O)', 'P(U)', 'P_Diff', 'CV_ML', 'CV_Over', 'CV_HA', ODDS]

features = ['P(A)', 'P_Diff', 'Odds_Over', 'CV_HA', 'Odds_H', 'Over_Line', 'P(U)', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'CV_Over', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']

# %%
def cria_setup(seed = 2023, features = features):
    cls = setup(data = treino,
            ignore_features = [x for x in treino.columns.to_list() if x not in features and x != TARGET],
            target = TARGET,
            train_size = 0.5,
            normalize = True,
            normalize_method = 'minmax',
            session_id = seed,
            remove_outliers = True,
            fix_imbalance = True,
            verbose = False
            )

# %%
cria_setup(seed = 2023, features = features)

xtrain_treino = get_config('X_train')
ytrain_treino = get_config('y_train')
xtrain_teste = get_config('X_test')
ytrain_teste = get_config('y_test')

real_treino = pd.concat([xtrain_treino, ytrain_treino], axis=1)
real_teste = pd.concat([xtrain_teste, ytrain_teste],  axis=1)

# %%
top = compare_models(exclude=['catboost', 'dummy'], fold = 5, sort='precision', n_select=14)
# Out:
# <style type="text/css">
# #T_67883 th {
#   text-align: left;
# }
# #T_67883_row0_col0, #T_67883_row0_col1, #T_67883_row0_col2, #T_67883_row0_col3, #T_67883_row0_col5, #T_67883_row0_col6, #T_67883_row0_col7, #T_67883_row1_col0, #T_67883_row1_col2, #T_67883_row1_col3, #T_67883_row1_col4, #T_67883_row1_col5, #T_67883_row2_col0, #T_67883_row2_col4, #T_67883_row2_col6, #T_67883_row2_col7, #T_67883_row3_col0, #T_67883_row3_col1, #T_67883_row3_col2, #T_67883_row3_col3, #T_67883_row3_col4, #T_67883_row3_col5, #T_67883_row3_col6, #T_67883_row3_col7, #T_67883_row4_col0, #T_67883_row4_col1, #T_67883_row4_col2, #T_67883_row4_col3, #T_67883_row4_col4, #T_67883_row4_col5, #T_67883_row4_col6, #T_67883_row4_col7, #T_67883_row5_col0, #T_67883_row5_col1, #T_67883_row5_col2, #T_67883_row5_col3, #T_67883_row5_col4, #T_67883_row5_col5, #T_67883_row5_col6, #T_67883_row5_col7, #T_67883_row6_col0, #T_67883_row6_col1, #T_67883_row6_col2, #T_67883_row6_col3, #T_67883_row6_col4, #T_67883_row6_col5, #T_67883_row6_col6, #T_67883_row6_col7, #T_67883_row7_col0, #T_67883_row7_col1, #T_67883_row7_col2, #T_67883_row7_col3, #T_67883_row7_col4, #T_67883_row7_col5, #T_67883_row7_col6, #T_67883_row7_col7, #T_67883_row8_col0, #T_67883_row8_col1, #T_67883_row8_col2, #T_67883_row8_col3, #T_67883_row8_col4, #T_67883_row8_col5, #T_67883_row8_col6, #T_67883_row8_col7, #T_67883_row9_col0, #T_67883_row9_col1, #T_67883_row9_col2, #T_67883_row9_col3, #T_67883_row9_col4, #T_67883_row9_col5, #T_67883_row9_col6, #T_67883_row9_col7, #T_67883_row10_col0, #T_67883_row10_col1, #T_67883_row10_col2, #T_67883_row10_col3, #T_67883_row10_col4, #T_67883_row10_col5, #T_67883_row10_col6, #T_67883_row10_col7, #T_67883_row11_col0, #T_67883_row11_col1, #T_67883_row11_col2, #T_67883_row11_col3, #T_67883_row11_col4, #T_67883_row11_col5, #T_67883_row11_col6, #T_67883_row11_col7, #T_67883_row12_col0, #T_67883_row12_col1, #T_67883_row12_col2, #T_67883_row12_col3, #T_67883_row12_col4, #T_67883_row12_col5, #T_67883_row12_col6, #T_67883_row12_col7, #T_67883_row13_col0, #T_67883_row13_col1, #T_67883_row13_col2, #T_67883_row13_col3, #T_67883_row13_col4, #T_67883_row13_col5, #T_67883_row13_col6, #T_67883_row13_col7 {
#   text-align: left;
# }
# #T_67883_row0_col4, #T_67883_row1_col1, #T_67883_row1_col6, #T_67883_row1_col7, #T_67883_row2_col1, #T_67883_row2_col2, #T_67883_row2_col3, #T_67883_row2_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_67883_row0_col8, #T_67883_row1_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_67883_row2_col8, #T_67883_row3_col8, #T_67883_row4_col8, #T_67883_row5_col8, #T_67883_row6_col8, #T_67883_row7_col8, #T_67883_row8_col8, #T_67883_row9_col8, #T_67883_row10_col8, #T_67883_row11_col8, #T_67883_row12_col8, #T_67883_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_67883">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67883_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_67883_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_67883_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_67883_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_67883_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_67883_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_67883_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_67883_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_67883_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67883_level0_row0" class="row_heading level0 row0" >svm</th>
#       <td id="T_67883_row0_col0" class="data row0 col0" >SVM - Linear Kernel</td>
#       <td id="T_67883_row0_col1" class="data row0 col1" >0.4686</td>
#       <td id="T_67883_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_67883_row0_col3" class="data row0 col3" >0.4653</td>
#       <td id="T_67883_row0_col4" class="data row0 col4" >0.5986</td>
#       <td id="T_67883_row0_col5" class="data row0 col5" >0.4122</td>
#       <td id="T_67883_row0_col6" class="data row0 col6" >-0.0725</td>
#       <td id="T_67883_row0_col7" class="data row0 col7" >-0.0765</td>
#       <td id="T_67883_row0_col8" class="data row0 col8" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_67883_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_67883_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_67883_row1_col1" class="data row1 col1" >0.5371</td>
#       <td id="T_67883_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_67883_row1_col3" class="data row1 col3" >0.5411</td>
#       <td id="T_67883_row1_col4" class="data row1 col4" >0.5860</td>
#       <td id="T_67883_row1_col5" class="data row1 col5" >0.5617</td>
#       <td id="T_67883_row1_col6" class="data row1 col6" >0.0717</td>
#       <td id="T_67883_row1_col7" class="data row1 col7" >0.0723</td>
#       <td id="T_67883_row1_col8" class="data row1 col8" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_67883_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_67883_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_67883_row2_col1" class="data row2 col1" >0.5371</td>
#       <td id="T_67883_row2_col2" class="data row2 col2" >0.5171</td>
#       <td id="T_67883_row2_col3" class="data row2 col3" >0.5721</td>
#       <td id="T_67883_row2_col4" class="data row2 col4" >0.5787</td>
#       <td id="T_67883_row2_col5" class="data row2 col5" >0.5734</td>
#       <td id="T_67883_row2_col6" class="data row2 col6" >0.0655</td>
#       <td id="T_67883_row2_col7" class="data row2 col7" >0.0663</td>
#       <td id="T_67883_row2_col8" class="data row2 col8" >0.0420</td>
#     </tr>
#     <tr>
#       <th id="T_67883_level0_row3" class="row_heading level0 row3" >nb</th>
#       <td id="T_67883_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_67883_row3_col1" class="data row3 col1" >0.5029</td>
#       <td id="T_67883_row3_col2" class="data row3 col2" >0.4724</td>
#       <td id="T_67883_row3_col3" class="data row3 col3" >0.5089</td>
#       <td id="T_67883_row3_col4" class="data row3 col4" >0.5459</td>
#       <td id="T_67883_row3_col5" class="data row3 col5" >0.5257</td>
#       <td id="T_67883_row3_col6" class="data row3 col6" >0.0036</td>
#       <td id="T_67883_row3_col7" class="data row3 col7" >0.0032</td>
#       <td id="T_67883_row3_col8" class="data row3 col8" >0.0440</td>
#     </tr>
#     <tr>
#       <th id="T_67883_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_67883_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_67883_row4_col1" class="data row4 col1" >0.4857</td>
#       <td id="T_67883_row4_col2" class="data row4 col2" >0.4665</td>
#       <td id="T_67883_row4_col3" class="data row4 col3" >0.5316</td>
#       <td id="T_67883_row4_col4" class="data row4 col4" >0.5321</td>
#       <td id="T_67883_row4_col5" class="data row4 col5" >0.5273</td>
#       <td id="T_67883_row4_col6" class="data row4 col6" >-0.0374</td>
#       <td id="T_67883_row4_col7" class="data row4 col7" >-0.0361</td>
#       <td id="T_67883_row4_col8" class="data row4 col8" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_67883_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_67883_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_67883_row5_col1" class="data row5 col1" >0.4629</td>
#       <td id="T_67883_row5_col2" class="data row5 col2" >0.4399</td>
#       <td id="T_67883_row5_col3" class="data row5 col3" >0.4789</td>
#       <td id="T_67883_row5_col4" class="data row5 col4" >0.5070</td>
#       <td id="T_67883_row5_col5" class="data row5 col5" >0.4901</td>
#       <td id="T_67883_row5_col6" class="data row5 col6" >-0.0776</td>
#       <td id="T_67883_row5_col7" class="data row5 col7" >-0.0790</td>
#       <td id="T_67883_row5_col8" class=
# Processing:   0%|          | 0/74 [00:00<?, ?it/s]

# %%
model = create_model('rf', cross_validation=False, return_train_score=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9e143">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e143_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9e143_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9e143_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9e143_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9e143_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9e143_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9e143_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e143_level0_row0" class="row_heading level0 row0" >Test</th>
#       <td id="T_9e143_row0_col0" class="data row0 col0" >0.5029</td>
#       <td id="T_9e143_row0_col1" class="data row0 col1" >0.5102</td>
#       <td id="T_9e143_row0_col2" class="data row0 col2" >0.5567</td>
#       <td id="T_9e143_row0_col3" class="data row0 col3" >0.5510</td>
#       <td id="T_9e143_row0_col4" class="data row0 col4" >0.5538</td>
#       <td id="T_9e143_row0_col5" class="data row0 col5" >-0.0074</td>
#       <td id="T_9e143_row0_col6" class="data row0 col6" >-0.0074</td>
#     </tr>
#     <tr>
#       <th id="T_9e143_level0_row1" class="row_heading level0 row1" >Train</th>
#       <td id="T_9e143_row1_col0" class="data row1 col0" >0.9771</td>
#       <td id="T_9e143_row1_col1" class="data row1 col1" >0.9982</td>
#       <td id="T_9e143_row1_col2" class="data row1 col2" >0.9792</td>
#       <td id="T_9e143_row1_col3" class="data row1 col3" >0.9792</td>
#       <td id="T_9e143_row1_col4" class="data row1 col4" >0.9792</td>
#       <td id="T_9e143_row1_col5" class="data row1 col5" >0.9539</td>
#       <td id="T_9e143_row1_col6" class="data row1 col6" >0.9539</td>
#     </tr>
#   </tbody>
# </table>

# %%
def filtra_resultados(_df, filtro = 0):
    _df = _df[_df['prediction_label'] == 1]

    if filtro == 1:
        _df = _df[((_df['Over_Line'] > 155))]
    
    return _df

# %%
def calcula_profit(_df, stake = 1):
    _df.loc[(_df[TARGET] == 1), 'PL_BF_Predictions'] = (_df[ODDS] - 1) * stake
    _df.loc[(_df[TARGET] == 0), 'PL_BF_Predictions'] = - stake

    return _df

def exibe_metricas(_df, total, stake = 1, return_metrics = False):
    plb = _df['PL_BF_Predictions'].sum()
    entradas = _df.shape[0]
    wr = round((_df[_df[TARGET] == 1].shape[0] / entradas), 2)
    oddback = (_df[ODDS].mean())
    med_gain = _df[_df[TARGET] == 1]['PL_BF_Predictions'].mean()
    med_loss = _df[_df[TARGET] == 0]['PL_BF_Predictions'].mean()
    roi = plb / entradas
    porc_ent = entradas / total
    ev = (wr*stake*med_gain) + ((1-wr)*med_loss*stake)

    if return_metrics == False:
        print(f'PL: {plb:.2f} | ROI: {100*roi:.2f}% | Prec.: {wr:.2f}')
        print(f'Odd média: {oddback:.2f} ({1/oddback:.2f} WR)')
        print(f'Média Gain: {med_gain:.2f} | Média Loss: {med_loss:.2f}')
        print(f'EM: {ev:.2f}')
        print(f'{entradas} entradas em {total} jogos ({100*porc_ent:.2f}%)')
    else:
        return_metrics == True
        metrics = [plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev]
        return metrics

def exibe_grafico(_df):
    _df.sort_index(inplace=True)
    _df.reset_index(drop=True, inplace=True)
    _df['hbacu'] = _df['PL_BF_Predictions'].cumsum()
    _df['hbacu'].plot.line(figsize=(7,2))
    plt.show()

def treina_modelo(modelo, data):
    _df = predict_model(modelo, data, verbose = False)
    _df = _df.merge(df[[TARGET]], left_index=True, right_index=True, how='left')
    if f'{TARGET}_x' in _df.columns.tolist():
        _df.rename(columns={f'{TARGET}_x': TARGET}, inplace=True)
        _df.drop(columns=f'{TARGET}_y', inplace=True)
    
    return _df

def info_modelo(modelo, data, stake = 1, filtro = 0):
    total = data.shape[0]

    _df = treina_modelo(modelo, data)
    _df = filtra_resultados(_df, filtro=filtro)
    _df = calcula_profit(_df, stake)
    exibe_metricas(_df, total, stake)
    exibe_grafico(_df)
    
    return _df

# %%
mdl = model
flt = 1
# df_tr = info_modelo(mdl, real_treino, filtro = flt)
df_teste = info_modelo(mdl, real_teste, filtro = flt)
# df_comp = info_modelo(mdl, treino, filtro = flt)
# Out:
# PL: 8.60 | ROI: 11.32% | Prec.: 0.59
# Odd média: 1.88 (0.53 WR)
# Média Gain: 0.88 | Média Loss: -1.00
# EM: 0.11
# 76 entradas em 175 jogos (43.43%)

# %%
df_val = info_modelo(mdl, val, filtro = flt)
# Out:
# PL: -3.54 | ROI: -3.31% | Prec.: 0.52
# Odd média: 1.85 (0.54 WR)
# Média Gain: 0.85 | Média Loss: -1.00
# EM: -0.04
# 107 entradas em 350 jogos (30.57%)

# %%
aux_comp = treina_modelo(mdl, real_teste)
aux_comp = filtra_resultados(aux_comp, filtro = flt)
plt.axvline(x=len(aux_comp), color='red', linestyle='--')
df_completo = info_modelo(mdl, pd.concat([real_teste, val]), filtro = flt)
# Out:
# PL: 5.06 | ROI: 2.77% | Prec.: 0.55
# Odd média: 1.86 (0.54 WR)
# Média Gain: 0.86 | Média Loss: -1.00
# EM: 0.02
# 183 entradas em 525 jogos (34.86%)

# %% [markdown]
# # Comparação de modelos

# %% [markdown]
# ### Escolhendo os modelos

# %%
FILTRO = 1
CONJUNTO = 'teste_val'

for i in range(14):
    try:
        if CONJUNTO == 'teste_val':
            print(f'{top[i].__class__.__name__} (i = {i})\n')
            aux_tr = treina_modelo(top[i], real_teste)
            aux_tr = filtra_resultados(aux_tr, filtro = FILTRO)
            plt.axvline(x=len(aux_tr), color='red', linestyle='--')
            aux = info_modelo(top[i], pd.concat([real_teste, val]), filtro = FILTRO)
        elif CONJUNTO == 'val':
            print(f'{top[i].__class__.__name__} (i = {i})\n')
            aux = info_modelo(top[i], val, filtro = FILTRO)
        elif CONJUNTO == 'teste':
            print(f'{top[i].__class__.__name__} (i = {i})\n')
            aux = info_modelo(top[i], real_teste, filtro = FILTRO)
    except:
        print(f'O modelo apresentou um erro.\n')
        pass
# Out:
# SGDClassifier (i = 0)
#
# PL: -2.86 | ROI: -2.78% | Prec.: 0.52
# Odd média: 1.87 (0.54 WR)
# Média Gain: 0.85 | Média Loss: -1.00
# EM: -0.04
# 103 entradas em 525 jogos (19.62%)
# RidgeClassifier (i = 1)
#
# PL: 7.45 | ROI: 3.58% | Prec.: 0.56
# Odd média: 1.86 (0.54 WR)
# Média Gain: 0.86 | Média Loss: -1.00
# EM: 0.04
# 208 entradas em 525 jogos (39.62%)
# LogisticRegression (i = 2)
#
# PL: 1.47 | ROI: 0.69% | Prec.: 0.54
# Odd média: 1.85 (0.54 WR)
# Média Gain: 0.85 | Média Loss: -1.00
# EM: -0.00
# 213 entradas em 525 jogos (40.57%)
# GaussianNB (i = 3)
#
# PL: 3.45 | ROI: 1.90% | Prec.: 0.55
# Odd média: 1.84 (0.54 WR)
# Média Gain: 0.84 | Média Loss: -1.00
# EM: 0.01
# 182 entradas em 525 jogos (34.67%)
# AdaBoostClassifier (i = 4)
#
# PL: 0.93 | ROI: 0.43% | Prec.: 0.54
# Odd média: 1.86 (0.54 WR)
# Média Gain: 0.85 | Média Loss: -1.00
# EM: 0.00
# 216 entradas em 525 jogos (41.14%)
# KNeighborsClassifier (i = 5)
#
# PL: 4.57 | ROI: 2.36% | Prec.: 0.55
# Odd média: 1.86 (0.54 WR)
# Média Gain: 0.86 | Média Loss: -1.00
# EM: 0.02
# 194 entradas em 525 jogos (36.95%)
# QuadraticDiscriminantAnalysis (i = 6)
#
# PL: -6.95 | ROI: -3.02% | Prec.: 0.52
# Odd média: 1.86 (0.54 WR)
# Média Gain: 0.86 | Média Loss: -1.00
# EM: -0.03
# 230 entradas em 525 jogos (43.81%)
# LinearDiscriminantAnalysis (i = 7)
#
# PL: 12.75 | ROI: 7.50% | Prec.: 0.58
# Odd média: 1.87 (0.53 WR)
# Média Gain: 0.86 | Média Loss: -1.00
# EM: 0.08
# 170 entradas em 525 jogos (32.38%)
# GradientBoostingClassifier (i = 8)
#
# PL: 3.46 | ROI: 1.76% | Prec.: 0.55
# Odd média: 1.84 (0.54 WR)
# Média Gain: 0.84 | Média Loss: -1.00
# EM: 0.01
# 197 entradas em 525 jogos (37.52%)
# DecisionTreeClassifier (i = 9)
#
# PL: -5.98 | ROI: -3.65% | Prec.: 0.52
# Odd média: 1.86 (0.54 WR)
# Média Gain: 0.86 | Média Loss: -1.00
# EM: -0.03
# 164 entradas em 525 jogos (31.24%)
# RandomForestClassifier (i = 10)
#
# PL: 5.06 | ROI: 2.77% | Prec.: 0.55
# Odd média: 1.86 (0.54 WR)
# Média Gain: 0.86 | Média Loss: -1.00
# EM: 0.02
# 183 entradas em 525 jogos (34.86%)
# ExtraTreesClassifier (i = 11)
#
# PL: 7.13 | ROI: 3.68% | Prec.: 0.56
# Odd média: 1.85 (0.54 WR)
# Média Gain: 0.85 | Média Loss: -1.00
# EM: 0.03
# 194 entradas em 525 jogos (36.95%)
# XGBClassifier (i = 12)
#
# PL: -0.93 | ROI: -0.47% | Prec.: 0.54
# Odd média: 1.86 (0.54 WR)
# Média Gain: 0.86 | Média Loss: -1.00
# EM: 0.00
# 200 entradas em 525 jogos (38.10%)
# LGBMClassifier (i = 13)
#
# PL: 1.24 | ROI: 0.69% | Prec.: 0.54
# Odd média: 1.86 (0.54 WR)
# Média Gain: 0.86 | Média Loss: -1.00
# EM: 0.00
# 181 entradas em 525 jogos (34.48%)

# %%
blended18 = blend_models(estimator_list = [top[1], top[8]], fold = 5, verbose=False)

# %%
model_list = [top[1], top[8], blended18]

# %% [markdown]
# ### Resultados

# %%
FILTRO = 2

for item in model_list:
    try:
        print(f'{item.__class__.__name__}\n')
        aux_tr = treina_modelo(item, real_teste)
        aux_tr = filtra_resultados(aux_tr, filtro = FILTRO)
        plt.axvline(x=len(aux_tr), color='red', linestyle='--')
        aux_total = treina_modelo(item, val1)
        aux_total = filtra_resultados(aux_total, filtro = FILTRO)
        plt.axvline(x=len(aux_total) + len(aux_tr), color='blue', linestyle='--')
        aux = info_modelo(item, pd.concat([real_teste, val]), filtro = FILTRO)
    except:
        print(f'O modelo apresentou um erro.\n')
        pass
# Out:
# GaussianNB
#
# PL: 26.46 | ROI: 11.92% | Prec.: 0.54
# Odd média: 2.11 (0.47 WR)
# Média Gain: 1.07 | Média Loss: -1.00
# EM: 0.12
# 222 entradas em 1637 jogos (13.56%)
# KNeighborsClassifier
#
# PL: 19.83 | ROI: 11.53% | Prec.: 0.53
# Odd média: 2.14 (0.47 WR)
# Média Gain: 1.11 | Média Loss: -1.00
# EM: 0.12
# 172 entradas em 1637 jogos (10.51%)
# VotingClassifier
#
# PL: 19.81 | ROI: 9.43% | Prec.: 0.53
# Odd média: 2.10 (0.48 WR)
# Média Gain: 1.05 | Média Loss: -1.00
# EM: 0.09
# 210 entradas em 1637 jogos (12.83%)

# %% [markdown]
# # Script qcut

# %%
# df_cut1 = df_treino.copy()
df_cut = df_comp.copy()
# df_cut = pd.concat([df_cut1, df_cut2])

# %%
variaveis = features.copy()
variaveis.append('prediction_score')

for var in variaveis:
    try:
        nome = f'Cat_{var}'
        # Usa qcut para definir os grupos
        df_cut[nome]  = pd.qcut(df_cut[var], q = 5)

        target = 'PL_BF_Predictions'
        pivot_table = pd.pivot_table(df_cut,
                                    values=target,
                                    index=[nome],
                                    aggfunc=['sum', 'count']
                                    )
        

        pivot_table['ratio'] = pivot_table[('sum', target)] / pivot_table[('count', target)]

        aux_treino = pivot_table[pivot_table['ratio'] != 0]


        print(var)
        print(aux_treino)
        print()
        print('\n\n')
        print('------------------------------------------------')
        print('\n\n')
    except:
        pass
# Out:
# P(A)
#                               sum             count     ratio
#                 PL_BF_Predictions PL_BF_Predictions
# Cat_P(A)
# (0.0899, 0.311]          6.360000                37  0.171892
# (0.311, 0.386]          -1.240000                37 -0.033514
# (0.386, 0.463]          14.280000                36  0.396667
# (0.463, 0.592]           2.930000                40  0.073250
# (0.592, 0.98]            3.710001                34  0.109118
#
#
#
#
# ------------------------------------------------
#
#
#
# P_Diff
#                                sum             count     ratio
#                  PL_BF_Predictions PL_BF_Predictions
# Cat_P_Diff
# (0.0257, 0.0393]          6.920000                37  0.187027
# (0.0393, 0.0441]          1.910000                38  0.050263
# (0.0441, 0.0617]          9.690001                36  0.269167
# (0.0617, 0.0703]          3.300001                37  0.089189
# (0.0703, 0.0929]          4.220001                36  0.117222
#
#
#
#
# ------------------------------------------------
#
#
#
# Odds_H
#                                           sum             count     ratio
#                             PL_BF_Predictions PL_BF_Predictions
# Cat_Odds_H
# (1.0190000000000001, 1.336]          6.360000                37  0.171892
# (1.336, 1.504]                       0.300000                37  0.008108
# (1.504, 1.706]                      10.830000                36  0.300833
# (1.706, 2.22]                        7.760000                37  0.209730
# (2.22, 16.5]                         0.790001                37  0.021351
#
#
#
#
# ------------------------------------------------
#
#
#
# Over_Line
#                                sum             count     ratio
#                  PL_BF_Predictions PL_BF_Predictions
# Cat_Over_Line
# (131.499, 155.5]             -2.25                41 -0.054878
# (155.5, 159.5]                3.80                39  0.097436
# (159.5, 163.5]                5.57                34  0.163824
# (163.5, 172.5]               12.86                34  0.378235
# (172.5, 226.5]                6.06                36  0.168333
#
#
#
#
# ------------------------------------------------
#
#
#
# Odds_A
#                                          sum             count     ratio
#                            PL_BF_Predictions PL_BF_Predictions
# Cat_Odds_A
# (1.0190000000000001, 1.69]          0.620001                39  0.015897
# (1.69, 2.16]                        6.020000                35  0.172000
# (2.16, 2.59]                       14.280000                36  0.396667
# (2.59, 3.22]                       -1.240000                37 -0.033514
# (3.22, 11.0]                        6.360000                37  0.171892
#
#
#
#
# ------------------------------------------------
#
#
#
# CV_ML
#                               sum             count     ratio
#                 PL_BF_Predictions PL_BF_Predictions
# Cat_CV_ML
# (-0.001, 0.198]              5.93                37  0.160270
# (0.198, 0.313]               4.86                40  0.121500
# (0.313, 0.48]               11.80                35  0.337143
# (0.48, 0.671]                3.83                36  0.106389
# (0.671, 1.25]               -0.38                36 -0.010556
#
#
#
#
# ------------------------------------------------
#
#
#
# HA_Line
#                               sum             count     ratio
#                 PL_BF_Predictions PL_BF_Predictions
# Cat_HA_Line
# (-18.501, -7.5]          4.660000                42  0.110952
# (-7.5, -4.5]            12.190001                44  0.277045
# (-4.5, -2.5]             6.180000                35  0.176571
# (-2.5, 1.5]              2.660000                31  0.085806
# (1.5, 18.5]              0.350001                32  0.010938
#
#
#
#
# ------------------------------------------------
#
#
#
# P(H)
#                               sum             count     ratio
#                 PL_BF_Predictions PL_BF_Predictions
# Cat_P(H)
# (0.0596, 0.451]          0.790001                37  0.021351
# (0.451, 0.586]           7.760000                37  0.209730
# (0.586, 0.665]          10.830000                36  0.300833
# (0.665, 0.749]           0.300000                37  0.008108
# (0.749, 0.98]            6.360000                37  0.171892
#
#
#
#
# ------------------------------------------------
#
#
#
# prediction_score
#                                    sum             count     ratio
#                      PL_BF_Predictions PL_BF_Predictions
# Cat_prediction_score
# (0.499, 0.529]                   -3.26                37 -0.088108
# (0.529, 0.565]                    2.35                37  0.063514
# (0.565, 0.62]                     1.60                36  0.044444
# (0.62, 0.724]                    11.54                37  0.311892
# (0.724, 0.986]                   13.81                37  0.373243
#
#
#
#
# ------------------------------------------------

# %%
_df = _df[((_df['Avg_Retornos_BH'] >= -0.35) & (_df['Avg_Retornos_BH'] < 0.35)) | ((_df['Avg_Retornos_BH'] >= 3.7) & (_df['Avg_Retornos_BH'] < 5))]

_df = _df[((_df['Over_Line'] < 218) | (_df['Over_Line'] > 155))]

# %%
# display(df_cut2.groupby('Cat_DP_Odds_Geral_H')['DP_Odds_Geral_H'].describe())

# %% [markdown]
# # Script variáveis

# %%
colunas = ['Odds_H', 'Odds_A', 'Over_Line', 'Odds_Over', 'Odds_Under', 'HA_Line',
       'HA_Odds_H', 'HA_Odds_A', 'P(H)', 'P(A)', 'P(O)', 'P(U)', 'P_Diff', 'Porc_Over_Home',
       'Porc_Over_Away', 'Avg_CG_H', 'DP_CG_H',
       'CV_CG_H', 'Avg_CG_A', 'DP_CG_A', 'CV_CG_A', 'MediaCustoGolHome',
       'MediaCustoGolAway', 'Last_CG_H', 'Last_CG_A', 'Acima_Last_CG_H',
       'Acima_Last_CG_A', 'Abaixo_Last_CG_H', 'Abaixo_Last_CG_A', 'CV_ML',
       'CV_Over', 'CV_HA', 'Retornos_BH_Acu', 'Avg_Retornos_BH', 'Custo_Retorno_BH',
       'Avg_Porc_BH_Bookie', 'Avg_Porc_BH_Real', 'Dist_Porc_BH',
       'Retornos_BA_Acu', 'Avg_Retornos_BA', 'Custo_Retorno_BA',
       'Avg_Porc_BA_Bookie', 'Avg_Porc_BA_Real', 'Dist_Porc_BA']

colunas = ['Odds_H', 'Odds_A', 'Odds_Over', 'Odds_Under', 'Over_Line',  'HA_Line', 'HA_Odds_H', 'HA_Odds_A', 'P(H)', 'P(A)', 
       'P(O)', 'P(U)', 'P_Diff', 'CV_ML',
       'CV_Over', 'CV_HA']

# %%
import random

def pegar_elementos_aleatorios(lista):
    # Gerar um número aleatório entre 2 e 7
    num_elementos = random.randint(5, 15)

    # Garantir que o número de elementos não ultrapasse o tamanho da lista
    num_elementos = min(num_elementos, len(lista))

    # Selecionar elementos aleatórios da lista
    elementos_aleatorios = random.sample(lista, num_elementos)

    return elementos_aleatorios

# %%
def cria_modelo(fts, _seed = 2023, _filtro = 0):
        try:
                cria_setup(features=fts, seed = _seed)

                model = create_model('lr', verbose = False, fold = 5)
                tab = pull()
                prec_model = (tab.loc['Mean', 'Prec.'])
                previsoes = predict_model(model, verbose = False)

                stake = 1

                total = previsoes.shape[0]

                previsoes = previsoes[previsoes['prediction_label'] == 1]
                previsoes = filtra_resultados(previsoes, filtro = _filtro)

                previsoes.loc[(previsoes[TARGET] == 1), 'PL_BF_Predictions'] = (previsoes[ODDS] - 1) * stake
                previsoes.loc[(previsoes[TARGET] == 0), 'PL_BF_Predictions'] = - stake

                plb = previsoes['PL_BF_Predictions'].sum()
                entradas = previsoes.shape[0]
                wr = round((previsoes[previsoes[TARGET] == 1].shape[0] / entradas), 2)
                oddback = previsoes[previsoes['prediction_label'] == 1][ODDS].mean()
                med_gain = previsoes[previsoes[TARGET] == 1]['PL_BF_Predictions'].mean()
                med_loss = previsoes[previsoes[TARGET] == 0]['PL_BF_Predictions'].mean()
                roi = plb / entradas
                porc_ent = entradas / total
                ev = (wr*stake*med_gain) + ((1-wr)*med_loss*stake)

                metrics = [prec_model, plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev]

                return metrics
        except Exception as e:
                print(e)
                return [0, 0, 0, 0, 0, 0, 0, 0, 0]

# %%
melhor_PL = -10000

for i in range(20):
    feats = pegar_elementos_aleatorios(colunas)
    feats.append(ODDS)

    metrics = cria_modelo(fts=feats)
    prec_model, plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev = metrics
            
    print(f'Rodada {i+1}')
    if plb > melhor_PL:
        melhor_PL = plb
        print(f'**Novo melhor**')
        print(f'Precision: {prec_model:.4f}')
        print(f'PL: {plb:.2f} | ROI: {100*roi:.2f}% | EM: {ev:.2f} | Prec.: {wr:.2f} | Entradas: {porc_ent:.2f}')
        print(f'features = {feats}\n')
    print()
# Out:
# Rodada 1
# **Novo melhor**
# Precision: 0.5744
# PL: 2.43 | ROI: 2.17% | EM: 0.01 | Prec.: 0.54 | Entradas: 0.64
# features = ['Odds_A', 'CV_Over', 'Odds_H', 'Odds_Over', 'Over_Line', 'P(H)', 'P(A)', 'Odds_Under', 'HA_Odds_H', 'P(O)', 'P_Diff', 'Odds']
#
#
# Rodada 2
# **Novo melhor**
# Precision: 0.5120
# PL: 6.38 | ROI: 10.29% | EM: 0.11 | Prec.: 0.60 | Entradas: 0.35
# features = ['Odds_Over', 'P(A)', 'HA_Odds_H', 'P(O)', 'CV_ML', 'P_Diff', 'Odds_A', 'CV_HA', 'P(U)', 'HA_Odds_A', 'Odds_H', 'P(H)', 'Odds']
#
#
# Rodada 3
# **Novo melhor**
# Precision: 0.5787
# PL: 7.05 | ROI: 7.34% | EM: 0.07 | Prec.: 0.57 | Entradas: 0.55
# features = ['P(A)', 'P_Diff', 'Odds_Over', 'CV_HA', 'Odds_H', 'Over_Line', 'P(U)', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'CV_Over', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']
#
#
# Rodada 4
# **Novo melhor**
# Precision: 0.4825
# PL: 8.43 | ROI: 11.87% | EM: 0.13 | Prec.: 0.61 | Entradas: 0.41
# features = ['P(U)', 'Odds_A', 'HA_Odds_H', 'P(A)', 'HA_Odds_A', 'Odds_H', 'CV_Over', 'HA_Line', 'P_Diff', 'Odds_Over', 'Odds']
#
#
# Rodada 5
#
# Rodada 6
#
# Rodada 7
#
# Rodada 8
#
# Rodada 9
#
# Rodada 10
#
# Rodada 11
#
# Rodada 12
#
# Rodada 13
#
# Rodada 14
#
# Rodada 15
#
# Rodada 16
#
# Rodada 17
#
# Rodada 18
#
# Rodada 19
#
# Rodada 20

# %%
Rodada 4
**Novo melhor**
Precision: 0.4825
PL: 8.43 | ROI: 11.87% | EM: 0.13 | Prec.: 0.61 | Entradas: 0.41
features = ['P(U)', 'Odds_A', 'HA_Odds_H', 'P(A)', 'HA_Odds_A', 'Odds_H', 'CV_Over', 'HA_Line', 'P_Diff', 'Odds_Over', 'Odds']

Rodada 3
**Novo melhor**
Precision: 0.5787
PL: 7.05 | ROI: 7.34% | EM: 0.07 | Prec.: 0.57 | Entradas: 0.55
features = ['P(A)', 'P_Diff', 'Odds_Over', 'CV_HA', 'Odds_H', 'Over_Line', 'P(U)', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'CV_Over', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']

# %% [markdown]
# # Segundo filtro

# %%
fits = ['P(A)', 'P_Diff', 'Odds_Over', 'CV_HA', 'Odds_H', 'Over_Line', 'P(U)', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'CV_Over', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']

# %%
metrics = cria_modelo(fits)
prec_model, plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev = metrics

print('---------------------- BASE ----------------------')
print(f'Precision: {prec_model:.4f}')
print(f'PL: {plb:.2f} | ROI: {100*roi:.2f}% | EM: {ev:.2f} | Prec.: {wr:.2f} | Entradas: {porc_ent:.2f}')
print(f'fits = {fits}\n')
print('--------------------------------------------------')
melhor_PL = plb

for i in range(len(fits) - 1):
    feat = fits[i]
    fits.pop(i)
    print(f'Removido: {feat}')

    metrics = cria_modelo(fits)
    prec_model, plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev = metrics

    if plb >= melhor_PL:
        print('*** NOVO MELHOR ***')
        melhor_PL = plb
    print(f'Precision: {prec_model:.4f}')
    print(f'PL: {plb:.2f} | ROI: {100*roi:.2f}% | EM: {ev:.2f} | Prec.: {wr:.2f} | Entradas: {porc_ent:.2f}')
    print(f'fits = {fits}\n')
    fits.insert(i, feat)
    print()
# Out:
# ---------------------- BASE ----------------------
# Precision: 0.5787
# PL: 7.05 | ROI: 7.34% | EM: 0.07 | Prec.: 0.57 | Entradas: 0.55
# fits = ['P(A)', 'P_Diff', 'Odds_Over', 'CV_HA', 'Odds_H', 'Over_Line', 'P(U)', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'CV_Over', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']
#
# --------------------------------------------------
# Removido: P(A)
# Precision: 0.5477
# PL: 1.73 | ROI: 1.71% | EM: 0.01 | Prec.: 0.54 | Entradas: 0.58
# fits = ['P_Diff', 'Odds_Over', 'CV_HA', 'Odds_H', 'Over_Line', 'P(U)', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'CV_Over', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']
#
#
# Removido: P_Diff
# Precision: 0.5606
# PL: 0.77 | ROI: 0.75% | EM: 0.01 | Prec.: 0.54 | Entradas: 0.58
# fits = ['P(A)', 'Odds_Over', 'CV_HA', 'Odds_H', 'Over_Line', 'P(U)', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'CV_Over', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']
#
#
# Removido: Odds_Over
# Precision: 0.5510
# PL: -0.46 | ROI: -0.45% | EM: -0.01 | Prec.: 0.53 | Entradas: 0.59
# fits = ['P(A)', 'P_Diff', 'CV_HA', 'Odds_H', 'Over_Line', 'P(U)', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'CV_Over', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']
#
#
# Removido: CV_HA
# Precision: 0.5887
# PL: 6.16 | ROI: 6.04% | EM: 0.06 | Prec.: 0.57 | Entradas: 0.58
# fits = ['P(A)', 'P_Diff', 'Odds_Over', 'Odds_H', 'Over_Line', 'P(U)', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'CV_Over', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']
#
#
# Removido: Odds_H
# Precision: 0.5742
# PL: 2.90 | ROI: 2.96% | EM: 0.03 | Prec.: 0.55 | Entradas: 0.56
# fits = ['P(A)', 'P_Diff', 'Odds_Over', 'CV_HA', 'Over_Line', 'P(U)', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'CV_Over', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']
#
#
# Removido: Over_Line
# Precision: 0.5108
# PL: 5.73 | ROI: 8.19% | EM: 0.09 | Prec.: 0.59 | Entradas: 0.40
# fits = ['P(A)', 'P_Diff', 'Odds_Over', 'CV_HA', 'Odds_H', 'P(U)', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'CV_Over', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']
#
#
# Removido: P(U)
# Precision: 0.5051
# PL: 4.74 | ROI: 4.56% | EM: 0.05 | Prec.: 0.56 | Entradas: 0.59
# fits = ['P(A)', 'P_Diff', 'Odds_Over', 'CV_HA', 'Odds_H', 'Over_Line', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'CV_Over', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']
#
#
# Removido: Odds_A
# Precision: 0.5395
# PL: 1.13 | ROI: 1.20% | EM: 0.01 | Prec.: 0.54 | Entradas: 0.54
# fits = ['P(A)', 'P_Diff', 'Odds_Over', 'CV_HA', 'Odds_H', 'Over_Line', 'P(U)', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'CV_Over', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']
#
#
# Removido: HA_Odds_H
# Precision: 0.5004
# PL: 3.69 | ROI: 3.73% | EM: 0.05 | Prec.: 0.56 | Entradas: 0.57
# fits = ['P(A)', 'P_Diff', 'Odds_Over', 'CV_HA', 'Odds_H', 'Over_Line', 'P(U)', 'Odds_A', 'CV_ML', 'Odds_Under', 'CV_Over', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']
#
#
# Removido: CV_ML
# Precision: 0.5492
# PL: 2.04 | ROI: 2.15% | EM: 0.03 | Prec.: 0.55 | Entradas: 0.54
# fits = ['P(A)', 'P_Diff', 'Odds_Over', 'CV_HA', 'Odds_H', 'Over_Line', 'P(U)', 'Odds_A', 'HA_Odds_H', 'Odds_Under', 'CV_Over', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']
#
#
# Removido: Odds_Under
# Precision: 0.5473
# PL: 0.47 | ROI: 0.52% | EM: 0.01 | Prec.: 0.54 | Entradas: 0.52
# fits = ['P(A)', 'P_Diff', 'Odds_Over', 'CV_HA', 'Odds_H', 'Over_Line', 'P(U)', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'CV_Over', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']
#
#
# Removido: CV_Over
# Precision: 0.5393
# PL: 1.46 | ROI: 1.45% | EM: 0.01 | Prec.: 0.54 | Entradas: 0.58
# fits = ['P(A)', 'P_Diff', 'Odds_Over', 'CV_HA', 'Odds_H', 'Over_Line', 'P(U)', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'HA_Line', 'P(H)', 'HA_Odds_A', 'Odds']
#
#
# Removido: HA_Line
# Precision: 0.5386
# PL: 1.85 | ROI: 1.95% | EM: 0.02 | Prec.: 0.55 | Entradas: 0.54
# fits = ['P(A)', 'P_Diff', 'Odds_Over', 'CV_HA', 'Odds_H', 'Over_Line', 'P(U)', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'CV_Over', 'P(H)', 'HA_Odds_A', 'Odds']
#
#
# Removido: P(H)
# Precision: 0.5477
# PL: 1.73 | ROI: 1.71% | EM: 0.01 | Prec.: 0.54 | Entradas: 0.58
# fits = ['P(A)', 'P_Diff', 'Odds_Over', 'CV_HA', 'Odds_H', 'Over_Line', 'P(U)', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'CV_Over', 'HA_Line', 'HA_Odds_A', 'Odds']
#
#
# Removido: HA_Odds_A
# Precision: 0.5181
# PL: 0.16 | ROI: 0.14% | EM: 0.01 | Prec.: 0.54 | Entradas: 0.64
# fits = ['P(A)', 'P_Diff', 'Odds_Over', 'CV_HA', 'Odds_H', 'Over_Line', 'P(U)', 'Odds_A', 'HA_Odds_H', 'CV_ML', 'Odds_Under', 'CV_Over', 'HA_Line', 'P(H)', 'Odds']

# %% [markdown]
# # Cross validation

# %%
ftrs = ['Avg_Porc_BA_Real', 'P(A)', 'P(O)', 'MediaCustoGolAway', 'HA_Odds_H', 'CV_Over', 'Retornos_BH_Acu', 'P(U)', 'Avg_Porc_BA_Bookie', 'DP_CG_H', 'Retornos_BA_Acu', 'Last_CG_H', 'Porc_Over_Away', 'Avg_Porc_BH_Real', 'CV_CG_H', 'Odds']

# %%
results = []
seeds = random.sample(range(0, 9999), 10)

for i in range(len(seeds)):

        cria_setup(seed=seeds[i], features=ftrs)

        cross_model = create_model('lr', verbose = False, cross_validation=False)
        
        previsoes = predict_model(cross_model, real_teste, verbose = False)
        previsoes = previsoes.merge(df[ODDS], left_index=True, right_index=True, how='left')
        if f'{ODDS}_x' in previsoes.columns.tolist():
                previsoes.rename(columns={f'{ODDS}_x': ODDS}, inplace=True)
                previsoes.drop(columns=f'{ODDS}_y', inplace=True)

        stake = 1

        total = previsoes.shape[0]

        previsoes = previsoes[(previsoes['prediction_label'] == 1)]

        previsoes.loc[(previsoes[TARGET] == 1), 'PL_BF_Predictions'] = (previsoes[ODDS] - 1) * stake
        previsoes.loc[(previsoes[TARGET] == 0), 'PL_BF_Predictions'] = - stake

        ############ Filtro ############
        previsoes = filtra_resultados(previsoes, filtro = 0)
        previsoes = calcula_profit(previsoes)
        metrics = exibe_metricas(previsoes, total = total, return_metrics=True)
        plb, wr, oddback, med_gain, med_loss, roi, porc_ent, ev = metrics
        
        results.append(wr)

        print(f'Fold {i+1} (seed {seeds[i]})')
        print(f'PL: {plb:.2f} | ROI: {100*roi:.2f}% | EM: {ev:.2f} | Prec.: {wr:.2f} | Entradas: {porc_ent:.2f}')
        print()

print(f'Média: {np.mean(results):.2f} | DP: {np.std(results):.2f}')
# Out:
# Fold 1 (seed 9839)
# PL: -1.70 | ROI: -0.67% | EM: -0.01 | Prec.: 0.64 | Entradas: 0.51
#
# Fold 2 (seed 457)
# PL: -10.97 | ROI: -4.27% | EM: -0.04 | Prec.: 0.62 | Entradas: 0.51
#
# Fold 3 (seed 5673)
# PL: -7.25 | ROI: -2.70% | EM: -0.03 | Prec.: 0.63 | Entradas: 0.54
#
# Fold 4 (seed 2960)
# PL: -6.15 | ROI: -2.44% | EM: -0.03 | Prec.: 0.63 | Entradas: 0.50
#
# Fold 5 (seed 4170)
# PL: -0.36 | ROI: -0.14% | EM: -0.00 | Prec.: 0.64 | Entradas: 0.52
#
# Fold 6 (seed 2715)
# PL: -2.58 | ROI: -0.98% | EM: -0.02 | Prec.: 0.63 | Entradas: 0.53
#
# Fold 7 (seed 4190)
# PL: -2.06 | ROI: -0.89% | EM: -0.01 | Prec.: 0.64 | Entradas: 0.46
#
# Fold 8 (seed 1100)
# PL: -2.54 | ROI: -1.06% | EM: -0.01 | Prec.: 0.64 | Entradas: 0.48
#
# Fold 9 (seed 4678)
# PL: -6.83 | ROI: -2.71% | EM: -0.03 | Prec.: 0.63 | Entradas: 0.50
#
# Fold 10 (seed 2480)
# PL: -10.90 | ROI: -4.31% | EM: -0.04 | Prec.: 0.62 | Entradas: 0.51
#
# Média: 0.63 | DP: 0.01

# %% [markdown]
# # Entradas Aleatórias

# %%
def new_random_model(_val, _n):

    for i in range(_n):
        random_df = _val.copy()
        random_df['Entrada'] = [random.choice([0, 1]) for _ in range(len(random_df))]

        random_df = random_df[random_df['Entrada'] == 1]
        random_df.loc[(random_df[TARGET] == 1), 'PL'] = (random_df[ODDS] - 1)
        random_df.loc[(random_df[TARGET] == 0), 'PL'] = - 1
        
        random_df.sort_values('Date', inplace=True)
        random_df.reset_index(drop=True, inplace=True)
        random_df['hbacu'] = random_df['PL'].cumsum()
        random_df['hbacu'].plot.line(figsize=(12,6))
    
    plt.show()

# %%
new_random_model(val, 10)
